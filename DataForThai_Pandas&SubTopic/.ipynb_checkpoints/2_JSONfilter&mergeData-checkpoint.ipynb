# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import os
import json
from pandas import json_normalize
# pd.__version__

# %%
topic_file = '/Users/bew/Downloads/DataForThai_jupyter/DataForThai_Pandas&SubTopic/SubTopic_dataforthai.csv'
topic_table = pd.read_csv(topic_file)


topic_table['รหัส'] = topic_table['รหัส'].astype(str)
# Function to add '0' to strings of length 4
def add_zero(s):
    if len(s) == 4:
        return '0' + s
    else:
        return s
# Applying the function to the DataFrame
topic_table['รหัส'] = topic_table['รหัส'].apply(lambda x: add_zero(x))


# topic_table.dtypes
topic_table = topic_table[:196] # 10771 # update index (ไม่จำเป็นต้อง Up แค่ไม่ให้ Run เกินต้องการ)
# topic_table = topic_table[topic_table['รหัส']=='01450']
# print(topic_table)
# max(topic_table['จำนวนหน้า'])
topic_table
# Out:
#       รหัส                                       ประเภทธุรกิจ  จำนวน  \
# 0    01111                       การปลูกข้าวโพดที่ใช้เมล็ดแก่     24
# 1    01112               การปลูกธัญพืช (ยกเว้นข้าวและข้าวโพด)     34
# 2    01113                               การปลูกพืชตระกูลถั่ว     15
# 3    01114                                  การปลูกถั่วเหลือง      3
# 4    01115                การปลูกพืชน้ำมัน (ยกเว้นถั่วเหลือง)     10
# ..     ...                                                ...    ...
# 191  10752  การผลิตอาหารปรุงสำเร็จบรรจุในภาชนะปิดสนิทโดยวิ...    147
# 192  10761                                        การผลิตกาแฟ    360
# 193  10762                                          การผลิตชา     79
# 194  10769            การผลิตสมุนไพรผงสำหรับชงเป็นเครื่องดื่ม    118
# 195  10771            การผลิตเครื่องเทศและเครื่องแกงสำเร็จรูป    159
#
#      จำนวนหน้า
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 191          1
# 192          1
# 193          1
# 194          1
# 195          1
#
# [196 rows x 4 columns]

# %%
# topic_for_file = topic_table[topic_table['รหัส'] == no_topic]
# topic_for_file

# %%
# # Read JSON file
# file_path = f'/Users/bew/Downloads/WebScrapperFor_DataForThai/Target/01111.json'  # Replace with your file path

# df = pd.read_json(file_path)

# # # Load JSON data into DataFrame
# # df = json_normalize(json_data)  # Use pd.DataFrame(json_data) if the JSON is already flat

# # df['สถานะ'] = df['สถานะ'].astype("string")
# df.dtypes
# # df

# %%
import pandas as pd
import os

# Initialize an empty DataFrame for the result
result = pd.DataFrame()

lastId = "10211" # update 'lastID' เพื่อไม่อ่านข้อมูลเดิม เพราะค้นหาข้อมูลมาทับ
value = ""

for index, row in topic_table.iterrows():
    
    value1 = row['รหัส']
    value2 = row['ประเภทธุรกิจ']
    
    if (int(value1) <= int(lastId)): continue
    
    # Construct the file path
    file_path = f'/Users/bew/Downloads/WebScrapperFor_DataForThai/Target/{value1}.json'
    
    # Check if the file exists
    if os.path.exists(file_path):
        try:
            # Read JSON file
            df = pd.read_json(file_path)
            
            # Add a new column with the business type
#             df['ประกอบธุรกิจ'] = value2
            
            # Concatenate the current DataFrame to the result DataFrame
            result = pd.concat([result, df], axis=0)
        
        except ValueError as e:
            print(f"Error reading JSON file at {file_path}: {e}")
    else:
        print(f"File not found: {file_path}")
    value = value1

print(f"lastId = {value1}")
# Out:
# File not found: /Users/bew/Downloads/WebScrapperFor_DataForThai/Target/10300.json
# File not found: /Users/bew/Downloads/WebScrapperFor_DataForThai/Target/10306.json
# File not found: /Users/bew/Downloads/WebScrapperFor_DataForThai/Target/10614.json
# File not found: /Users/bew/Downloads/WebScrapperFor_DataForThai/Target/10623.json
# File not found: /Users/bew/Downloads/WebScrapperFor_DataForThai/Target/10734.json
# lastId = 10771

# %%
# Reset the index of the final result DataFrame
result = result.reset_index(drop=True)

# result

# %%
result.columns.tolist()

result['เบอร์โทร'] = np.nan
# new_order = ['เลขทะเบียน', 'ชื่อบริษัทภาษาไทย', 'ชื่อบริษัทภาษาอังกฤษ', 'ประกอบธุรกิจ', 'หมวดธุรกิจ', 'สถานะ',
#              'วันที่จดทะเบียน', 'ทุนจดทะเบียน', 'ที่ตั้ง', 'ข้อมูลสำหรับการติดต่อ', 'เบอร์โทร', 'Website', 'ก่อตั้งโดย',
#              'หลักทรัพย์', 'ที่มา', 'สมัครงาน / ดูตำแหน่งงานว่าง', 'วันที่ร้าง', 'วันที่เลิก']
# result = result[new_order]
# result

# %%
# for index, row in topic_table.iterrows():
    
#     value1 = row['รหัส']
#     value2 = row['ประเภทธุรกิจ']
    
#     # Read JSON file
#     file_path = f'/Users/bew/Downloads/WebScrapperFor_DataForThai/Target/{value1}.json'  # Replace with your file path

#     df = pd.read_json(file_path)
    
#     df['ประกอบธุรกิจ'] = value2
    
#     result = pd.concat([result, df], axis=0)
    
    
# result

# %%
# result = result.drop(columns=['สมัครงาน / ดูตำแหน่งงานว่าง', 'วันที่ร้าง', 'หลักทรัพย์'])

result = result.applymap(str)
# result['เลขทะเบียน'] = result['เลขทะเบียน'].map(str)
# result['สถานะ'] = result['สถานะ'].astype("string")


# Step 1: Remove commas from the strings
result['ทุนจดทะเบียน'] = result['ทุนจดทะเบียน'].str.replace(',', '')
result['ทุนจดทะเบียน'] = result['ทุนจดทะเบียน'].str.replace(' บาท', '')
# Step 2: Convert the strings to numeric type (int or float)
result['ทุนจดทะเบียน'] = pd.to_numeric(result['ทุนจดทะเบียน'])

result.dtypes
# Out:
# เลขทะเบียน                     object
# ประกอบธุรกิจ                   object
# หมวดธุรกิจ                     object
# สถานะ                          object
# วันที่จดทะเบียน                object
# ทุนจดทะเบียน                    int64
# ข้อมูลสำหรับติดต่อ             object
# ที่ตั้ง                        object
# ชื่อบริษัทภาษาอังกฤษ           object
# ชื่อบริษัทภาษาไทย              object
# ข้อมูลสำหรับการติดต่อ          object
# ที่มา                          object
# สมัครงาน / ดูตำแหน่งงานว่าง    object
# เว็บไซต์                       object
# หลักทรัพย์                     object
# วันที่เลิก                     object
# ก่อตั้งโดย                     object
# พิพากษาล้มละลาย                object
# ศาลสั่งพิทักษ์ทรัพย์           object
# เสร็จชำระบัญชี                 object
# วันที่ร้าง                     object
# เบอร์โทร                       object
# dtype: object

# %%
result = result[result['สถานะ']=='ยังดำเนินกิจการอยู่']
result = result[(result['ทุนจดทะเบียน'] >= 30000000)]

# def get_length(obj):
#     try:
#         return len(obj)
#     except TypeError:
#         return None

# for text in result['ทุนจดทะเบียน']:
#     print(text.apply(get_length))

# for index, row in result.iterrows():
    
#     value1 = row['เลขทะเบียน']
#     if value1.apply(len) != 13:
#         value1 = "0" + value1.astype(str)

result['เลขทะเบียน'] = "'0" + result['เลขทะเบียน'].astype(str)
# # Function to add '0' to strings of length 13
# def add_zero(s):
# #     s = str(s)  # Ensure the input is a string
#     if len(s) == 14:
#         return '0' + s
#     else:
#         return s

# # Applying the function to the DataFrame
# result['เลขทะเบียน'] = result['เลขทะเบียน'].apply(lambda x: add_zero(x))

# # Reset the index of the final result DataFrame
# result = result.reset_index(drop=True)

# result.dtypes

# %%
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' มกราคม ','/1/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' กุมภาพันธ์ ','/2/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' มีนาคม ','/3/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' เมษายน ','/4/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' พฤษภาคม ','/5/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' มิถุนายน ','/6/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' กรกฎาคม ','/7/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' สิงหาคม ','/8/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' กันยายน ','/9/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' ตุลาคม ','/10/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' พฤศจิกายน ','/11/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' ธันวาคม ','/12/')

# %%
result = result.reset_index(drop=True)
# result

# %%
# result.dtypes

# %%
file = '/Users/bew/Downloads/DataForThai_jupyter/FilterAndSearchData.csv'
df = pd.read_csv(file)

df_updated = pd.concat([df, result], ignore_index=True)
df_updated = df_updated.drop_duplicates(subset='เลขทะเบียน')
df_updated = df_updated.reset_index(drop=True)

df_updated.dtypes
df_updated
# Out:
#           เลขทะเบียน                                       ประกอบธุรกิจ  \
# 0     '0105523007276  ผลิตเมล็ดพันธุ์ข้าวโพดและข้าวฟ่าง จำหน่ายเมล็ด...
# 1     '0105539070673                                 จำหน่ายเมล็ดพันธุ์
# 2     '0105563169226                      เพาะปลูกผลิตผลทางการเกษตรกรรม
# 3     '0815524000023                              ประกอบกิจการเกษตรกรรม
# 4     '0105531018826                การเกษตรกรรมทุกชนิด และการให้บริการ
# ...              ...                                                ...
# 2283  '0105524027815              ผลิตและจำหน่ายน้ำพริกเผา น้ำจิ้มต่างๆ
# 2284  '0105556177031                              ผลิตสิ่งปรุงแต่งอาหาร
# 2285  '0205551019223  นำเข้า ผลิต จำหน่ายปลีกและส่ง สารปรับปรุงคุณภา...
# 2286  '0105543095111  นำเข้า ผลิตและจำหน่ายผลิตภัณฑ์ที่ใช้ในการบำรุง...
# 2287  '0105542095461  ผลิต จำหน่ายและส่งออกผลิตภัณฑ์อาหาร น้ำพริกเผา...
#
#                                              หมวดธุรกิจ                สถานะ  \
# 0                          การปลูกข้าวโพดที่ใช้เมล็ดแก่  ยังดำเนินกิจการอยู่
# 1                  การปลูกธัญพืช (ยกเว้นข้าวและข้าวโพด)  ยังดำเนินกิจการอยู่
# 2                                       การปลูกข้าวจ้าว  ยังดำเนินกิจการอยู่
# 3                  การปลูกธัญพืช (ยกเว้นข้าวและข้าวโพด)  ยังดำเนินกิจการอยู่
# 4                  การปลูกธัญพืช (ยกเว้นข้าวและข้าวโพด)  ยังดำเนินกิจการอยู่
# ...                                                 ...                  ...
# 2283  การผลิตผลิตภัณฑ์อาหารอื่น ๆ ซึ่งมิได้จัดประเภท...  ยังดำเนินกิจการอยู่
# 2284            การผลิตเครื่องเทศและเครื่องแกงสำเร็จรูป  ยังดำเนินกิจการอยู่
# 2285            การผลิตเครื่องเทศและเครื่องแกงสำเร็จรูป  ยังดำเนินกิจการอยู่
# 2286            การผลิตเครื่องเทศและเครื่องแกงสำเร็จรูป  ยังดำเนินกิจการอยู่
# 2287            การผลิตเครื่องเทศและเครื่องแกงสำเร็จรูป  ยังดำเนินกิจการอยู่
#
#      วันที่จดทะเบียน  ทุนจดทะเบียน Website  \
# 0          29/4/2523     245000000     NaN
# 1          26/6/2539     162000000     NaN
# 2         17/11/2563     100000000     NaN
# 3          17/9/2524      30000000     NaN
# 4          16/3/2531     150000000     NaN
# ...              ...           ...     ...
# 2283       22/9/2524      59000000     NaN
# 2284       1/11/2556     105000000     NaN
# 2285       20/8/2551     111000000     NaN
# 2286       9/10/2543     100000000     NaN
# 2287      13/12/2542      45000000     NaN
#
#                                              ก่อตั้งโดย  \
# 0     กรรมการ: นายกิตติพงษ์ ลิมปสุรัติ, นางจริยา วุฒ...
# 1     กรรมการ: นายโยชิฮิโร โอบาทาเกะ, นายเซน ทากามิย...
# 2                          กรรมการ: นางสาวอรวรรณ พัฒนพล
# 3     กรรมการ: นายบุญส่ง ลีลามั่นคง, นางสุรัตน์ โพธิ...
# 4     กรรมการ: นางสาววรรณี จันทร์ไกรวัล, นางณัฐนี ตุ...
# ...                                                 ...
# 2283                                                nan
# 2284                                                nan
# 2285                                                nan
# 2286                                                nan
# 2287                                                nan
#
#                                                 ที่ตั้ง  \
# 0     87 อาคารเอ็ม.ไทย ทาวเวอร์ ออลซีซันส์ เพลส ชั้น...
# 1     260 หมู่ที่ 13 ตำบลโนนท่อน อำเภอเมืองขอนแก่น จ...
# 2     71 อาคารเอจีอาร์ ชั้นที่ 4 ถนนเจริญราษฎร์ แขวง...
# 3     141 หมู่ที่ 2 ถนนเพชรเกษม ตำบลอ่าวลึกเหนือ อำเ...
# 4     109 หมู่ที่ 9 ถนนสุวรรณศร ตำบลดงขี้เหล็ก อำเภอ...
# ...                                                 ...
# 2283  68/10 หมู่ที่ 12 ถนนบรมราชชนนี แขวงศาลาธรรมสพน...
# 2284  88 อาคารเดอะปาร์ค ชั้น 11 ถนนรัชดาภิเษก แขวงคล...
# 2285  1/1 ซอยสุขาภิบาล 2 ซอย 11 แยก 2 แขวงประเวศ เขต...
# 2286  284 นิคมอุตสาหกรรมลาดกระบัง เขตทั่วไปโครงการ 3...
# 2287  50/1 ถนนมหาจักร แขวงคลองมหานาค เขตป้อมปราบศัตร...
#
#                               ชื่อบริษัทภาษาอังกฤษ  ...  \
# 0             PIONEER HI-BRED (THAILAND) CO., LTD.  ...
# 1                       SAKATA SIAM SEED CO., LTD.  ...
# 2                    SUBNAIDIN 666 COMPANY LIMITED  ...
# 3                                              NaN  ...
# 4                     MORI FOOD PRODUCTS CO., LTD.  ...
# ...                                            ...  ...
# 2283  PHIBOONCHAI MAEPRANOM THAICHIL PASTE CO.,LTD  ...
# 2284       PECAN DELUXE (THAILAND) COMPANY LIMITED  ...
# 2285                       FUSO(THAILAND) CO.,LTD.  ...
# 2286              V.MANE FILS (THAILAND) CO., LTD.  ...
# 2287                                                ...
#
#      สมัครงาน / ดูตำแหน่งงานว่าง วันที่ร้าง หลักทรัพย์ วันที่เลิก    เบอร์โทร  \
# 0      ดูตำแหน่งงานจาก JOBTOPGUN        NaN        NaN        NaN  '027922900
# 1                            NaN        NaN        NaN        NaN  '043001314
# 2                            NaN        NaN        NaN        NaN         NaN
# 3                            NaN        NaN        NaN        NaN  '075681136
# 4                            NaN        NaN        NaN        NaN         NaN
# ...                          ...        ...        ...        ...         ...
# 2283                         nan        nan        nan        nan         nan
# 2284                         nan        nan        nan        nan         nan
# 2285   ดูตำแหน่งงานจาก JOBTOPGUN        nan        nan        nan         nan
# 2286      ดูตำแหน่งงานจาก JOBSDB        nan        nan        nan         nan
# 2287                         nan        nan        nan        nan         nan
#
#                                      ข้อมูลสำหรับติดต่อ เสร็จชำระบัญชี  \
# 0                                                   NaN            NaN
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN            NaN
# ...                                                 ...            ...
# 2283  สมาชิก dataforthai.com สามารถดูข้อมูลการติดต่อ...            nan
# 2284  สมาชิก dataforthai.com สามารถดูข้อมูลการติดต่อ...            nan
# 2285  สมาชิก dataforthai.com สามารถดูข้อมูลการติดต่อ...            nan
# 2286  สมาชิก dataforthai.com สามารถดูข้อมูลการติดต่อ...            nan
# 2287  สมาชิก dataforthai.com สามารถดูข้อมูลการติดต่อ...            nan
#
#                      เว็บไซต์ พิพากษาล้มละลาย ศาลสั่งพิทักษ์ทรัพย์
# 0                         NaN             NaN                  NaN
# 1                         NaN             NaN                  NaN
# 2                         NaN             NaN                  NaN
# 3                         NaN             NaN                  NaN
# 4                         NaN             NaN                  NaN
# ...                       ...             ...                  ...
# 2283        www.maepranom.com             nan                  nan
# 2284                      nan             nan                  nan
# 2285  http://www.fusokk.co.jp             nan                  nan
# 2286      http://www.mane.com             nan                  nan
# 2287                      nan             nan                  nan
#
# [2288 rows x 23 columns]

# %%
# result[result['เลขทะเบียน'].str.len() != 13]

# %%
# result

# %%
file_name = 'FilterAndSearchData.csv'
file_path = '/Users/bew/Downloads/DataForThai_jupyter/'

# Combine the file path and file name
full_path = os.path.join(file_path, file_name)

# result.to_csv(full_path, sep=',', index=False, header=True, encoding='utf-8') # รอบ 1
df_updated.to_csv(full_path, sep=',', index=False, header=True, encoding='utf-8') # รอบ 2+

print('finish')
# Out:
# finish

# %%
# # Step 1: Remove commas from the strings
# df['Capital'] = df['Capital'].str.replace(',', '')

# # Step 2: Convert the strings to numeric type (int or float)
# df['Capital'] = pd.to_numeric(df['Capital'])

# # Display the DataFrame to verify the changes
# df
