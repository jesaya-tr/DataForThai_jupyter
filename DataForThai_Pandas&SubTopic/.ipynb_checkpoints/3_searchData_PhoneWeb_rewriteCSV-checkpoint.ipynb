# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import os
import json
from pandas import json_normalize
# pd.__version__

# %%
# import pandas as pd

# # สร้าง DataFrame ตัวอย่าง
# df1 = pd.DataFrame({
#     'key': ['A', 'B', 'C', 'D'],
#     'value1': [1, 2, 3, 4]
# })

# df2 = pd.DataFrame({
#     'key': ['B', 'D', 'E', 'F'],
#     'value1': ['foo', 'bar', 'baz', 'qux']
# })

# # โดยใช้ key เป็นตัวเชื่อม

# # inner_join_df = pd.merge(df1, df2, on='key', how='inner')
# # print("Inner Join:")
# # print(inner_join_df)

# # # Left Join
# # left_join_df = pd.merge(df1, df2, on='key', how='left')
# # print("\nLeft Join:")
# # print(left_join_df)

# # # Right Join
# # right_join_df = pd.merge(df1, df2, on='key', how='right')
# # print("\nRight Join:")
# # print(right_join_df)

# # # Outer Join
# # outer_join_df = pd.merge(df1, df2, on='key', how='outer')
# # print("\nOuter Join:")
# # print(outer_join_df)



# # outer_join_df = outer_join_df.drop(columns=['value1_y'])

# # # print(outer_join_df)
# # outer_join_df

# %%
# topic_file = '/Users/bew/Downloads/SubTopic_dataforthai.csv'
# topic_table = pd.read_csv(topic_file)


# topic_table['รหัส'] = topic_table['รหัส'].astype(str)
# # Function to add '0' to strings of length 4
# def add_zero(s):
#     if len(s) == 4:
#         return '0' + s
#     else:
#         return s
# # Applying the function to the DataFrame
# topic_table['รหัส'] = topic_table['รหัส'].apply(lambda x: add_zero(x))


# # topic_table.dtypes
# topic_table = topic_table[:15]
# # topic_table = topic_table[topic_table['รหัส']=='01450']
# # print(topic_table)
# # max(topic_table['จำนวนหน้า'])
# topic_table

# %%
file = '/Users/bew/Downloads/DataForThai_jupyter/FilterAndSearchData.csv'
df = pd.read_csv(file)

df
# Out:
#           เลขทะเบียน                                       ประกอบธุรกิจ  \
# 0     '0105523007276  ผลิตเมล็ดพันธุ์ข้าวโพดและข้าวฟ่าง จำหน่ายเมล็ด...
# 1     '0105539070673                                 จำหน่ายเมล็ดพันธุ์
# 2     '0105563169226                      เพาะปลูกผลิตผลทางการเกษตรกรรม
# 3     '0815524000023                              ประกอบกิจการเกษตรกรรม
# 4     '0105531018826                การเกษตรกรรมทุกชนิด และการให้บริการ
# ...              ...                                                ...
# 2339  '0775548000644  การผลิตเครื่องปรุงอาหารประจำโต๊ะและเครื่องประก...
# 2340  '0105546107854                      ผลิตและจำหน่ายสารสกัดจากยีสต์
# 2341  '0105517005879                                      ผลิตกรดซิตริก
# 2342  '0107562000483  ผลิตและจำหน่ายเครื่องปรุงรสอาหารและอาหารสำเร็จรูป
# 2343  '0105560133158  การผลิตเครื่องปรุงอาหารประจำโต๊ะและเครื่องประก...
#
#                                              หมวดธุรกิจ                สถานะ  \
# 0                          การปลูกข้าวโพดที่ใช้เมล็ดแก่  ยังดำเนินกิจการอยู่
# 1                  การปลูกธัญพืช (ยกเว้นข้าวและข้าวโพด)  ยังดำเนินกิจการอยู่
# 2                                       การปลูกข้าวจ้าว  ยังดำเนินกิจการอยู่
# 3                  การปลูกธัญพืช (ยกเว้นข้าวและข้าวโพด)  ยังดำเนินกิจการอยู่
# 4                  การปลูกธัญพืช (ยกเว้นข้าวและข้าวโพด)  ยังดำเนินกิจการอยู่
# ...                                                 ...                  ...
# 2339  การผลิตเครื่องปรุงอาหารประจำโต๊ะและเครื่องประก...  ยังดำเนินกิจการอยู่
# 2340  การผลิตเครื่องปรุงอาหารประจำโต๊ะและเครื่องประก...  ยังดำเนินกิจการอยู่
# 2341          การผลิตเคมีภัณฑ์อนินทรีย์ขั้นมูลฐานอื่น ๆ  ยังดำเนินกิจการอยู่
# 2342  การผลิตเครื่องปรุงอาหารประจำโต๊ะและเครื่องประก...  ยังดำเนินกิจการอยู่
# 2343  การผลิตเครื่องปรุงอาหารประจำโต๊ะและเครื่องประก...  ยังดำเนินกิจการอยู่
#
#      วันที่จดทะเบียน  ทุนจดทะเบียน Website  \
# 0          29/4/2523     245000000     NaN
# 1          26/6/2539     162000000     NaN
# 2         17/11/2563     100000000     NaN
# 3          17/9/2524      30000000     NaN
# 4          16/3/2531     150000000     NaN
# ...              ...           ...     ...
# 2339        9/2/2548     150000000     NaN
# 2340        9/9/2546      70000000     NaN
# 2341        2/5/2517      70000000     NaN
# 2342      16/12/2562    1559423020     NaN
# 2343       10/8/2560     961760500     NaN
#
#                                              ก่อตั้งโดย  \
# 0     กรรมการ: นายกิตติพงษ์ ลิมปสุรัติ, นางจริยา วุฒ...
# 1     กรรมการ: นายโยชิฮิโร โอบาทาเกะ, นายเซน ทากามิย...
# 2                          กรรมการ: นางสาวอรวรรณ พัฒนพล
# 3     กรรมการ: นายบุญส่ง ลีลามั่นคง, นางสุรัตน์ โพธิ...
# 4     กรรมการ: นางสาววรรณี จันทร์ไกรวัล, นางณัฐนี ตุ...
# ...                                                 ...
# 2339                                                NaN
# 2340                                                NaN
# 2341                                                NaN
# 2342                                                NaN
# 2343                                                NaN
#
#                                                 ที่ตั้ง  \
# 0     87 อาคารเอ็ม.ไทย ทาวเวอร์ ออลซีซันส์ เพลส ชั้น...
# 1     260 หมู่ที่ 13 ตำบลโนนท่อน อำเภอเมืองขอนแก่น จ...
# 2     71 อาคารเอจีอาร์ ชั้นที่ 4 ถนนเจริญราษฎร์ แขวง...
# 3     141 หมู่ที่ 2 ถนนเพชรเกษม ตำบลอ่าวลึกเหนือ อำเ...
# 4     109 หมู่ที่ 9 ถนนสุวรรณศร ตำบลดงขี้เหล็ก อำเภอ...
# ...                                                 ...
# 2339  77 หมู่ที่ 7 ตำบลบ่อนอก อำเภอเมืองประจวบคีรีขั...
# 2340  700/364 หมู่ที่ 6 ตำบลหนองไม้แดง อำเภอเมืองชลบ...
# 2341  231 หมู่ 4 ถนนสุขุมวิท ตำบลแพรกษา อำเภอเมืองสม...
# 2342  99/1 หมู่ที่ 4 ตำบลแคราย อำเภอกระทุ่มแบน จ.สมุ...
# 2343  518/5 อาคารมณียาเซ็นเตอร์ ชั้นที่ 6 ถนนเพลินจิ...
#
#                            ชื่อบริษัทภาษาอังกฤษ  ...  \
# 0          PIONEER HI-BRED (THAILAND) CO., LTD.  ...
# 1                    SAKATA SIAM SEED CO., LTD.  ...
# 2                 SUBNAIDIN 666 COMPANY LIMITED  ...
# 3                                           NaN  ...
# 4                  MORI FOOD PRODUCTS CO., LTD.  ...
# ...                                         ...  ...
# 2339                 YEARRA BUB COMPANY LIMITED  ...
# 2340          SPECIALTY BIOTECH COMPANY LIMITED  ...
# 2341        CITRIC ACIDINDUSTRY COMPANY LIMITED  ...
# 2342  NR INSTANT PRODUCE PUBLIC COMPANY LIMITED  ...
# 2343                       NRF CONSUMER LIMITED  ...
#
#      สมัครงาน / ดูตำแหน่งงานว่าง  วันที่ร้าง หลักทรัพย์ วันที่เลิก  \
# 0      ดูตำแหน่งงานจาก JOBTOPGUN         NaN        NaN        NaN
# 1                            NaN         NaN        NaN        NaN
# 2                            NaN         NaN        NaN        NaN
# 3                            NaN         NaN        NaN        NaN
# 4                            NaN         NaN        NaN        NaN
# ...                          ...         ...        ...        ...
# 2339     ดูตำแหน่งงานจาก JOBTHAI         NaN        NaN        NaN
# 2340                         NaN         NaN        NaN        NaN
# 2341                         NaN         NaN        NaN        NaN
# 2342                         NaN         NaN        NRF        NaN
# 2343                         NaN         NaN        NaN        NaN
#
#         เบอร์โทร                                 ข้อมูลสำหรับติดต่อ  \
# 0     '027922900                                                NaN
# 1     '043001314                                                NaN
# 2            NaN                                                NaN
# 3     '075681136                                                NaN
# 4            NaN                                                NaN
# ...          ...                                                ...
# 2339         NaN  สมาชิก dataforthai.com สามารถดูข้อมูลการติดต่อ...
# 2340         NaN                                                NaN
# 2341         NaN                                                NaN
# 2342         NaN  สมาชิก dataforthai.com สามารถดูข้อมูลการติดต่อ...
# 2343         NaN                                                NaN
#
#       เสร็จชำระบัญชี                    เว็บไซต์ พิพากษาล้มละลาย  \
# 0                NaN                         NaN             NaN
# 1                NaN                         NaN             NaN
# 2                NaN                         NaN             NaN
# 3                NaN                         NaN             NaN
# 4                NaN                         NaN             NaN
# ...              ...                         ...             ...
# 2339             NaN                         NaN             NaN
# 2340             NaN                         NaN             NaN
# 2341             NaN                         NaN             NaN
# 2342             NaN  https://www.nrinstant.com/             NaN
# 2343             NaN                         NaN             NaN
#
#       ศาลสั่งพิทักษ์ทรัพย์
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 2339                   NaN
# 2340                   NaN
# 2341                   NaN
# 2342                   NaN
# 2343                   NaN
#
# [2344 rows x 23 columns]

# %%
# result.columns.tolist()

# new_order = ['เลขทะเบียน', 'ชื่อบริษัทภาษาไทย', 'ชื่อบริษัทภาษาอังกฤษ', 'ประกอบธุรกิจ', 'หมวดธุรกิจ', 'สถานะ',
#              'วันที่จดทะเบียน', 'ทุนจดทะเบียน', 'ที่ตั้ง', 'ข้อมูลสำหรับการติดต่อ', 'เบอร์โทร', 'Website', 'ก่อตั้งโดย',
#              'หลักทรัพย์', 'ที่มา', 'สมัครงาน / ดูตำแหน่งงานว่าง', 'วันที่ร้าง', 'วันที่เลิก']
# result = result[new_order]
# result

# %%
# df.loc[df['เลขทะเบียน'] == "", 'เบอร์โทร'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""

# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""


# ไม่แน่ใจ = ไม่ใส่

# Index 12
# http://premsukfarmthailand.com/contact

# %%
import webbrowser

lastIndex = "1383" # เริ่ม -1 # Update 'lastIndex' ให้เริ่มค้นหา

for index, row in df.iterrows():
    value1 = row['เลขทะเบียน']
    value2 = row['ชื่อบริษัทภาษาไทย']
    value3 = row['ข้อมูลสำหรับการติดต่อ']
    value4 = row['เบอร์โทร']
    value5 = row['Website']
    value6 = row['ที่ตั้ง']
    value7 = row['ที่มา']
    
    if (index <= int(lastIndex)): continue
#     if (index <= int(lastIndex)): print("You already did:",index, "-", value1, "-", value2, "-", value3, "-", value4); continue
    
    print(f"\n")
    print(f"{index}: {value1} ---{value3} ---{value4} ---{value5} ---{value2}")
    print(f"         {value6}")
    print(f"         {value7}")
    company_search = value2.replace(' ', '+')
    url = f'https://www.google.com/search?q={company_search}+ติดต่อ'
    print(f"         {url}")
#     webbrowser.open(url)
    
    x = input('เบอร์โทร:')
    if x == '-' : break
    df.at[index, 'เบอร์โทร'] = f"'" + x.replace(' ', '').replace('-', '').replace('(', '').replace(')', '').replace('+66', '0')
#     value3 = x.replace(' ', '').str.replace('+66', '0')
#     str = str + f"\n# Index: {index}\nresult.loc[result['ชื่อบริษัทภาษาไทย'] == '{value1}', 'เบอร์โทร'] = '{value3}'\n"
    
    y = input('Website:')
#     if y == '-' : break
    df.at[index, 'Website'] = y
#     value4 = y
#     str = str + f"result.loc[result['ชื่อบริษัทภาษาไทย'] == '{value1}', 'Website'] = '{value4}'\n"
    
    lastIndex = index

df.loc[df['เบอร์โทร'] == "'", 'เบอร์โทร'] = np.nan

print(f"\nBreak at Index: {lastIndex}\n")

file_name = 'FilterAndSearchData.csv'
file_path = '/Users/bew/Downloads/DataForThai_jupyter/'

# Combine the file path and file namehttps://www.dataforthai.com/company/0105531008413/
full_path = os.path.join(file_path, file_name)

df.to_csv(full_path, sep=',', index=False, header=True, encoding='utf-8')

print('fill done')
# Out:
# 1384: '0105520000157 ---True ---nan ---nan ---บริษัท รวมอาหาร จำกัด
#          140 หมู่ที่ 2 ถนนเพชรเกษม ตำบลสระกะเทียม อำเภอเมืองนครปฐม จ.นครปฐม 73000
#          https://www.dataforthai.com/company/0105520000157/
#          https://www.google.com/search?q=บริษัท+รวมอาหาร+จำกัด+ติดต่อ
# เบอร์โทร:-
#
# Break at Index: 1383
#
# fill done

# %%
# print("Update file data test_fill to test")

# file_update = 'test.csv'
# file_path = '/Users/bew/Downloads/'

# # Combine the file path and file name
# full_path = os.path.join(file_path, file_update)

# df.to_csv(full_path, sep=',', index=False, header=True, encoding='utf-8')

# print("Finish Update")
