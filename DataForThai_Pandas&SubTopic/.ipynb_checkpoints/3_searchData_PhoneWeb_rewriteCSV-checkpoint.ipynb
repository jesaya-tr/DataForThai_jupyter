# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import os
import json
from pandas import json_normalize
# pd.__version__

# %%
# import pandas as pd

# # สร้าง DataFrame ตัวอย่าง
# df1 = pd.DataFrame({
#     'key': ['A', 'B', 'C', 'D'],
#     'value1': [1, 2, 3, 4]
# })

# df2 = pd.DataFrame({
#     'key': ['B', 'D', 'E', 'F'],
#     'value1': ['foo', 'bar', 'baz', 'qux']
# })

# # โดยใช้ key เป็นตัวเชื่อม

# # inner_join_df = pd.merge(df1, df2, on='key', how='inner')
# # print("Inner Join:")
# # print(inner_join_df)

# # # Left Join
# # left_join_df = pd.merge(df1, df2, on='key', how='left')
# # print("\nLeft Join:")
# # print(left_join_df)

# # # Right Join
# # right_join_df = pd.merge(df1, df2, on='key', how='right')
# # print("\nRight Join:")
# # print(right_join_df)

# # # Outer Join
# # outer_join_df = pd.merge(df1, df2, on='key', how='outer')
# # print("\nOuter Join:")
# # print(outer_join_df)



# # outer_join_df = outer_join_df.drop(columns=['value1_y'])

# # # print(outer_join_df)
# # outer_join_df

# %%
# topic_file = '/Users/bew/Downloads/SubTopic_dataforthai.csv'
# topic_table = pd.read_csv(topic_file)


# topic_table['รหัส'] = topic_table['รหัส'].astype(str)
# # Function to add '0' to strings of length 4
# def add_zero(s):
#     if len(s) == 4:
#         return '0' + s
#     else:
#         return s
# # Applying the function to the DataFrame
# topic_table['รหัส'] = topic_table['รหัส'].apply(lambda x: add_zero(x))


# # topic_table.dtypes
# topic_table = topic_table[:15]
# # topic_table = topic_table[topic_table['รหัส']=='01450']
# # print(topic_table)
# # max(topic_table['จำนวนหน้า'])
# topic_table

# %%
file = '/Users/bew/Downloads/DataForThai_jupyter/FilterAndSearchData.csv'
df = pd.read_csv(file)

df
# Out:
#           เลขทะเบียน                                       ประกอบธุรกิจ  \
# 0     '0105523007276  ผลิตเมล็ดพันธุ์ข้าวโพดและข้าวฟ่าง จำหน่ายเมล็ด...
# 1     '0105539070673                                 จำหน่ายเมล็ดพันธุ์
# 2     '0105563169226                      เพาะปลูกผลิตผลทางการเกษตรกรรม
# 3     '0815524000023                              ประกอบกิจการเกษตรกรรม
# 4     '0105531018826                การเกษตรกรรมทุกชนิด และการให้บริการ
# ...              ...                                                ...
# 1567  '0305562006097            การผลิตนมสด นมพาสเจอร์ไรส์ นมสเตอริไลน์
# 1568  '0105538028568  ผลิตและจำหน่ายนมเปรี้ยวพร้อมดื่มผลิตและจำหน่าย...
# 1569  '0105534064811  ผลิต และจำหน่ายนมเปรี้ยว,โยเกิร์ต ผลิต และจำหน...
# 1570  '0105561117636                           ผลิตโยเกิร์ตและนมเปรี้ยว
# 1571  '0105558152868  ผลิตและจำหน่ายผลิตภัณฑ์อาหารนม วิปปิ้งครีมและเ...
#
#                                 หมวดธุรกิจ                สถานะ  \
# ...

# %%
# result.columns.tolist()

# new_order = ['เลขทะเบียน', 'ชื่อบริษัทภาษาไทย', 'ชื่อบริษัทภาษาอังกฤษ', 'ประกอบธุรกิจ', 'หมวดธุรกิจ', 'สถานะ',
#              'วันที่จดทะเบียน', 'ทุนจดทะเบียน', 'ที่ตั้ง', 'ข้อมูลสำหรับการติดต่อ', 'เบอร์โทร', 'Website', 'ก่อตั้งโดย',
#              'หลักทรัพย์', 'ที่มา', 'สมัครงาน / ดูตำแหน่งงานว่าง', 'วันที่ร้าง', 'วันที่เลิก']
# result = result[new_order]
# result

# %%
# df.loc[df['เลขทะเบียน'] == "", 'เบอร์โทร'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""

df.loc[df['เลขทะเบียน'] == "'0215555005049", 'Website'] = "https://www.facebook.com/ryvvmushroom"
df.loc[df['เลขทะเบียน'] == "'0107537001501", 'Website'] = "http://www.paf-group.com/"
df.loc[df['เลขทะเบียน'] == "'0105538078905", 'Website'] = "www.eternalenergy.co.th"
df.loc[df['เลขทะเบียน'] == "'0115547008299", 'Website'] = "www.eternalenergy.co.th"
df.loc[df['เลขทะเบียน'] == "'0105552104942", 'Website'] = "https://www.promushroom.com/th"
df.loc[df['เลขทะเบียน'] == "'0925561001690", 'Website'] = "https://www.woodworkgroup.co.th/"
df.loc[df['เลขทะเบียน'] == "'0505535003285", 'Website'] = "http://www.unitedmushroom.com/"
df.loc[df['เลขทะเบียน'] == "'0105559128596", 'Website'] = "https://www.sungroup.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105526000574", 'Website'] = "www.tipco.net"
df.loc[df['เลขทะเบียน'] == "'0575552000582", 'Website'] = "https://preservefood.net/"
df.loc[df['เลขทะเบียน'] == "'0105524017208", 'Website'] = "th.advantaseeds.com"
df.loc[df['เลขทะเบียน'] == "'0105539082124", 'Website'] = "https://www.ssi-steel.com/"
df.loc[df['เลขทะเบียน'] == "'0505537002898", 'Website'] = "www.saithong.co.th"
df.loc[df['เลขทะเบียน'] == "'0105515004883", 'Website'] = "http://thaiwallpaper.com"
df.loc[df['เลขทะเบียน'] == "'0105562167033", 'Website'] = "https://www.easternspectrum.com/th/"
df.loc[df['เลขทะเบียน'] == "'0105564163892", 'Website'] = "https://canbis.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105563031984", 'Website'] = "https://winneragro.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105564092189", 'Website'] = "https://gsc-service.com/"
df.loc[df['เลขทะเบียน'] == "'0105552135511", 'Website'] = "https://www.thaieasterngroup.com/"
df.loc[df['เลขทะเบียน'] == "'0905555002094", 'Website'] = "https://www.southlandholding.com/th/"
df.loc[df['เลขทะเบียน'] == "'0925550000239", 'Website'] = "https://www.sritranggroup.com/th/home"
df.loc[df['เลขทะเบียน'] == "'0725556001131", 'Website'] = "https://www.xn--c3cscaqf8aw0b0i0a1dvf0a3f2a5d.com/"
df.loc[df['เลขทะเบียน'] == "'0125547003122", 'Website'] = "https://www.metroply.com/th/home-2"
df.loc[df['เลขทะเบียน'] == "'0105531059042", 'Website'] = "https://www.wangkanai.co.th/Default.aspx"
df.loc[df['เลขทะเบียน'] == "'0925553000434", 'Website'] = "https://www.woodworkgroup.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105544101573", 'Website'] = "https://www.ackfoodtech.com/wordpress/"
df.loc[df['เลขทะเบียน'] == "'0105560088659", 'Website'] = "https://soronbiotechnology.net/"
df.loc[df['เลขทะเบียน'] == "'0105564071793", 'Website'] = "https://nusacsr.com/"
df.loc[df['เลขทะเบียน'] == "'0115565002108", 'Website'] = "https://www.thaitex.com/home#intro"
df.loc[df['เลขทะเบียน'] == "'0105527029991", 'Website'] = "https://www.aguniversal.com/th/"
df.loc[df['เลขทะเบียน'] == "'0245551000760", 'Website'] = "https://www.sciencepark.or.th/th/"
df.loc[df['เลขทะเบียน'] == "'0625556000331", 'Website'] = "https://www.torchfarmer.com/"
df.loc[df['เลขทะเบียน'] == "'0395545000043", 'Website'] = "http://www.npfarm.com/#"
df.loc[df['เลขทะเบียน'] == "'0505528000306", 'Website'] = "https://www.fourt.co.th/"
df.loc[df['เลขทะเบียน'] == "'0705563001931", 'Website'] = "http://www.vcffeedmill.com/index.php"
df.loc[df['เลขทะเบียน'] == "'0745564003211", 'Website'] = "https://www.inteqcglobal.com/index"
df.loc[df['เลขทะเบียน'] == "'0745559003968", 'Website'] = "https://www.inteqcglobal.com/index"
df.loc[df['เลขทะเบียน'] == "'0735559007173", 'Website'] = "https://www.kcf.co.th"
df.loc[df['เลขทะเบียน'] == "'0405559003553", 'Website'] = "https://www.super-eggs.com/"
df.loc[df['เลขทะเบียน'] == "'0105554013634", 'Website'] = "https://pauldy.com/"
df.loc[df['เลขทะเบียน'] == "'0165545000193", 'Website'] = "https://www.tfg.co.th/th/home"
df.loc[df['เลขทะเบียน'] == "'0105518002938", 'Website'] = "https://www.ktfood.co.th/?me=en-home"
df.loc[df['เลขทะเบียน'] == "'0105521016944", 'Website'] = "https://www.ktfood.co.th/?me=en-home"
df.loc[df['เลขทะเบียน'] == "'0905552001909", 'Website'] = "https://lpf.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105524028536", 'Website'] = "https://www.gfpt.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105562036290", 'Website'] = "https://www.sungroup.co.th/index.php"
df.loc[df['เลขทะเบียน'] == "'0105543043707", 'Website'] = "https://www.sungroup.co.th/index.php"
df.loc[df['เลขทะเบียน'] == "'0605558001431", 'Website'] = "https://thaiento.com/"
df.loc[df['เลขทะเบียน'] == "'0925548000103", 'Website'] = "https://รังนกธรรมชาติ.com/"
df.loc[df['เลขทะเบียน'] == "'0935560000240", 'Website'] = "https://www.nongthongfarm.co.th/"
df.loc[df['เลขทะเบียน'] == "'0315565000987", 'Website'] = "https://www.facebook.com/people/RMC-ECO-Operation-CoLtd/100083382510569/"
df.loc[df['เลขทะเบียน'] == "'0105560176604", 'Website'] = "https://www.naturaharvest.com/"
df.loc[df['เลขทะเบียน'] == "'0105560214859", 'Website'] = "https://manitgroup.co.th/"
df.loc[df['เลขทะเบียน'] == "'0775548000652", 'Website'] = "https://yearrakarn.com/"
df.loc[df['เลขทะเบียน'] == "'0105562082542", 'Website'] = "https://symr.co.th/"
df.loc[df['เลขทะเบียน'] == "'0625552000212", 'Website'] = "https://www.yangyuengroup.com/"
df.loc[df['เลขทะเบียน'] == "'0625556000381", 'Website'] = "https://lpf.co.th/"
df.loc[df['เลขทะเบียน'] == "'0505563006692", 'Website'] = "https://www.kpagro.co.th/"
df.loc[df['เลขทะเบียน'] == "'0575556001940", 'Website'] = "https://rompothonggroup.com"
df.loc[df['เลขทะเบียน'] == "'0105547132259", 'Website'] = "https://www.leepattana.com/"
df.loc[df['เลขทะเบียน'] == "'0515560000413", 'Website'] = "https://golcondaasia.com/th/home-th/"
df.loc[df['เลขทะเบียน'] == "'0205545006484", 'Website'] = "https://www.kittiwanagroup.com/"
df.loc[df['เลขทะเบียน'] == "'0245548001483", 'Website'] = "http://www.uth.suankitti.com/Uth/"
df.loc[df['เลขทะเบียน'] == "'0905549002495", 'Website'] = "https://www.sif.co.th/"
df.loc[df['เลขทะเบียน'] == "'0745555002169", 'Website'] = "https://www.thaiunion.com/th/home"
df.loc[df['เลขทะเบียน'] == "'0745555003106", 'Website'] = "https://www.thaiunion.com/th/home"
df.loc[df['เลขทะเบียน'] == "'0745549001482", 'Website'] = "https://www.thaiunion.com/th/home"
df.loc[df['เลขทะเบียน'] == "'0105560214841", 'Website'] = "https://manitgroup.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105560214832", 'Website'] = "https://manitgroup.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105521004644", 'Website'] = "https://www.maygroup-thailand.com/"
df.loc[df['เลขทะเบียน'] == "'0845546002592", 'Website'] = "http://www.srisubanfarm.com"
df.loc[df['เลขทะเบียน'] == "'0105557105301", 'Website'] = "https://www.thaiunion.com/th/home"
df.loc[df['เลขทะเบียน'] == "'0107535000397", 'Website'] = "https://www.lannar.com/"
df.loc[df['เลขทะเบียน'] == "'0107558000148", 'Website'] = "https://www.sahakol.com/"
df.loc[df['เลขทะเบียน'] == "'0105539017543", 'Website'] = "https://www.sapthip.com/"
df.loc[df['เลขทะเบียน'] == "'0105533109209", 'Website'] = "https://www.pttep.com/en/home"
df.loc[df['เลขทะเบียน'] == "'0105561079971", 'Website'] = "https://www.pttep.com/en/home"
df.loc[df['เลขทะเบียน'] == "'0105522005016", 'Website'] = "https://www.pttep.com/en/home"
df.loc[df['เลขทะเบียน'] == "'0107535000206", 'Website'] = "https://www.pttep.com/en/home"
df.loc[df['เลขทะเบียน'] == "'0105539104535", 'Website'] = "https://www.ecothai.net/th/"
df.loc[df['เลขทะเบียน'] == "'0105530020975", 'Website'] = "https://www.bigth.com/th/"
df.loc[df['เลขทะเบียน'] == "'0105556005230", 'Website'] = "https://www.bgrimmpower.com/th/home"
df.loc[df['เลขทะเบียน'] == "'0105562120169", 'Website'] = "https://www.bigth.com/th/"
df.loc[df['เลขทะเบียน'] == "'0425547000121", 'Website'] = "https://ptkmining.com/"
df.loc[df['เลขทะเบียน'] == "'0105506001613", 'Website'] = "https://www.thaisarco.com/"
df.loc[df['เลขทะเบียน'] == "'0107537000467", 'Website'] = "www.boundandbeyond.co.th"
df.loc[df['เลขทะเบียน'] == "'0715554000481", 'Website'] = "http://www.sica-mtl.com/"
df.loc[df['เลขทะเบียน'] == "'0105535023964", 'Website'] = "https://www.thailandanthracite.com/"
df.loc[df['เลขทะเบียน'] == "'0715530000146", 'Website'] = "www.pandsgroup.com"
df.loc[df['เลขทะเบียน'] == "'0525535000090", 'Website'] = "https://patralampang.simdif.com/"
df.loc[df['เลขทะเบียน'] == "'0105556196922", 'Website'] = "http://www.rocksworldindustry.com/index.php"
df.loc[df['เลขทะเบียน'] == "'0105543036115", 'Website'] = "http://www.rocksworldindustry.com/index.php"
df.loc[df['เลขทะเบียน'] == "'0525540000221", 'Website'] = "https://www.lotushall.com/home.php"
df.loc[df['เลขทะเบียน'] == "'0107556000582", 'Website'] = "www.akararesources.com"
df.loc[df['เลขทะเบียน'] == "'0105526024589", 'Website'] = "https://msis.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105555009011", 'Website'] = "http://www.mcsenergythailand.com/"
df.loc[df['เลขทะเบียน'] == "'0107537002087", 'Website'] = "www.tongkahharbour.com"
df.loc[df['เลขทะเบียน'] == "'0735538002164", 'Website'] = "https://www.facebook.com/Kanjana.Silapun/"
df.loc[df['เลขทะเบียน'] == "'0125542000826", 'Website'] = "https://www.grandhomemart.com/"
df.loc[df['เลขทะเบียน'] == "'0825540000032", 'Website'] = "https://khaoborconstruction.com/"
df.loc[df['เลขทะเบียน'] == "'0195537000945", 'Website'] = "https://www.namhenggroup.com/stone/th/"
df.loc[df['เลขทะเบียน'] == "'0845541001059", 'Website'] = "https://www.facebook.com/srirathong/"
df.loc[df['เลขทะเบียน'] == "'0425535000147", 'Website'] = "https://www.facebook.com/p/บริษัท-บำรุงเทพ-การศิลา-จำกัด-100057609242610/ "
df.loc[df['เลขทะเบียน'] == "'0105535041954", 'Website'] = "https://www.facebook.com/buriramnawarat/"
df.loc[df['เลขทะเบียน'] == "'0735533001089", 'Website'] = "https://www.facebook.com/p/Pathomsila-Sahamitr-Co-Ltd-100072170872679/"
df.loc[df['เลขทะเบียน'] == "'0805552000822", 'Website'] = "https://www.ptg.co.th/Site/main"
df.loc[df['เลขทะเบียน'] == "'0505550004203", 'Website'] = "https://www.facebook.com/Pongsupakorn777/"
df.loc[df['เลขทะเบียน'] == "'0565535000090", 'Website'] = "https://www.facebook.com/pisitstone/"
df.loc[df['เลขทะเบียน'] == "'0105549124504", 'Website'] = "https://www.facebook.com/p/บริษัท-มรรคาสาธิต-จำกัด-100041371458139/"
df.loc[df['เลขทะเบียน'] == "'0165536000470", 'Website'] = "https://obobchanon.wixsite.com/khaoyaistonemill"
df.loc[df['เลขทะเบียน'] == "'0775536000423", 'Website'] = "https://www.facebook.com/p/โรงโม่หินชัยพัฒน์-100063618338633/"
df.loc[df['เลขทะเบียน'] == "'0845507000045", 'Website'] = "https://www.facebook.com/people/บริษัท-ศิลาชัยสุราษฎร์-จำกัด/100069653820796/"
df.loc[df['เลขทะเบียน'] == "'0675537000282", 'Website'] = "https://www.facebook.com/p/บริษัท-ศิลาทวีโชค-จำกัด-100064976890963/"
df.loc[df['เลขทะเบียน'] == "'0405540000583", 'Website'] = "https://www.decaarbyscg.com/"
df.loc[df['เลขทะเบียน'] == "'0725539000408", 'Website'] = "https://www.facebook.com/p/โรงโม่หินศิลาเพชรพลอยดี-100054424632573/"
df.loc[df['เลขทะเบียน'] == "'0723555000075", 'Website'] = "https://www.facebook.com/p/Sila-Petchsuphan-100063641246253/"
df.loc[df['เลขทะเบียน'] == "'0725537000010", 'Website'] = "https://www.facebook.com/Silamartsri/"
df.loc[df['เลขทะเบียน'] == "'0105524029036", 'Website'] = "https://www.facebook.com/silalertchit/"
df.loc[df['เลขทะเบียน'] == "'0715537000389", 'Website'] = "https://www.facebook.com/silasomboonsub/"
df.loc[df['เลขทะเบียน'] == "'0107556000531", 'Website'] = "https://www.stoneone.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105536080783", 'Website'] = "https://www.facebook.com/p/โรงโม่หิน-บริษัท-สมบูรณ์ศิลาทอง-จำกัด-100057256427477/"
df.loc[df['เลขทะเบียน'] == "'0505542000342", 'Website'] = "https://www.siamstone.co.th/"
df.loc[df['เลขทะเบียน'] == "'0835518000041", 'Website'] = "https://www.facebook.com/sahakijpuckdee/"
df.loc[df['เลขทะเบียน'] == "'0325539000061", 'Website'] = "https://www.facebook.com/p/บริษัท-สุรินทร์ศิลาทรัพย์-จำกัด-100063634205520/"
df.loc[df['เลขทะเบียน'] == "'0315536000214", 'Website'] = "https://www.facebook.com/hinpetchburiram/"
df.loc[df['เลขทะเบียน'] == "'0825539000016", 'Website'] = "https://www.facebook.com/p/Erawan-Asia-Mining-เหมืองเอราวัณเอเชีย-ขายหิน-100063702506261/"
df.loc[df['เลขทะเบียน'] == "'0107560000346", 'Website'] = "www.chememan.com"
df.loc[df['เลขทะเบียน'] == "'0105527011570", 'Website'] = "www.tongkahharbour.com"
df.loc[df['เลขทะเบียน'] == "'0635533000016", 'Website'] = "https://www.facebook.com/MAEPINGPANAKIT2019/"
df.loc[df['เลขทะเบียน'] == "'0645540000166", 'Website'] = "https://www.facebook.com/p/บริษัท-โรงโม่หินสุวรรณ-จำกัด-61550331458285/"
df.loc[df['เลขทะเบียน'] == "'0105501001160", 'Website'] = "https://sahachartsethakit.com/"
df.loc[df['เลขทะเบียน'] == "'0195522000022", 'Website'] = "https://www.surintomya.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105560037647", 'Website'] = "https://www.facebook.com/ccwr2560"
df.loc[df['เลขทะเบียน'] == "'0435554000084", 'Website'] = "https://www.facebook.com/jongrakconcrete/"
df.loc[df['เลขทะเบียน'] == "'0715535000217", 'Website'] = "https://www.facebook.com/SandYonghua/"
df.loc[df['เลขทะเบียน'] == "'0105557008127", 'Website'] = "https://kanok.co.th/"
df.loc[df['เลขทะเบียน'] == "'0335565000324", 'Website'] = "http://thasairungaroon.co.th"
df.loc[df['เลขทะเบียน'] == "'0735565004407", 'Website'] = "https://www.facebook.com/p/บริษัท-ปฐมศิริโชค-ทรายทอง-จำกัด-100094902691399/"
df.loc[df['เลขทะเบียน'] == "'0105523004293", 'Website'] = "http://www.promsuwan.com"
df.loc[df['เลขทะเบียน'] == "'0105559091854", 'Website'] = "https://www.facebook.com/AyutthayaLand2016/"
df.loc[df['เลขทะเบียน'] == "'0135547011087", 'Website'] = "https://www.truestone.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105543030958", 'Website'] = "https://www.chinchanagroup.com/"
df.loc[df['เลขทะเบียน'] == "'0107547000478", 'Website'] = "https://www.facebook.com/AseanPotash/"
df.loc[df['เลขทะเบียน'] == "'0105552106856", 'Website'] = "https://ipggroup.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105527034316", 'Website'] = "http://www.appc.co.th/th/index.html"
df.loc[df['เลขทะเบียน'] == "'0105537097221", 'Website'] = "https://www.psc.co.th/th/contact-us"
df.loc[df['เลขทะเบียน'] == "'0105491002142", 'Website'] = "https://www.facebook.com/panporpotov45/"
df.loc[df['เลขทะเบียน'] == "'0105515007947", 'Website'] = "https://www.wenggroup.com/"
df.loc[df['เลขทะเบียน'] == "'0105532030196", 'Website'] = "https://www.pipatkorn.com/"
df.loc[df['เลขทะเบียน'] == "'0805546000697", 'Website'] = "https://sinluang.com/"
df.loc[df['เลขทะเบียน'] == "'0105543052412", 'Website'] = "https://www.facebook.com/GWDCThailand/"
df.loc[df['เลขทะเบียน'] == "'0105551045217", 'Website'] = "https://thaikali.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105525040386", 'Website'] = "http://www.nov.com/"
df.loc[df['เลขทะเบียน'] == "'0105564070053", 'Website'] = "https://www.bgrimmpower.com/th/home"
df.loc[df['เลขทะเบียน'] == "'0105547049165", 'Website'] = "www.beacon-offshore.com"
df.loc[df['เลขทะเบียน'] == "'0105541001861", 'Website'] = "http://www.weatherford.com"
df.loc[df['เลขทะเบียน'] == "'0105549063793", 'Website'] = "https://www.valeuraenergy.com/"
df.loc[df['เลขทะเบียน'] == "'0105548005901", 'Website'] = "http://www.apicollc.com/home"
df.loc[df['เลขทะเบียน'] == "'0105551083607", 'Website'] = "www.elite-drilling.com"
df.loc[df['เลขทะเบียน'] == "'0105509004109", 'Website'] = " www.sts.co.th"
df.loc[df['เลขทะเบียน'] == "'0655555000990", 'Website'] = "www.changpinit.asia"
df.loc[df['เลขทะเบียน'] == "'0735546000752", 'Website'] = "https://www.facebook.com/sichonkarnsila/"
df.loc[df['เลขทะเบียน'] == "'0605556000799", 'Website'] = "https://kvsfreshproducts.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105533078141", 'Website'] = "https://www.facebook.com/p/บริษัท-บีฟู้ดส์โปรดักส์อินเตอร์เนชั่นเนล-จำกัด-100065125675729/"
df.loc[df['เลขทะเบียน'] == "'0705545000279", 'Website'] = "www.prakobbeef.co.th"
df.loc[df['เลขทะเบียน'] == "'0705556000917", 'Website'] = "https://www.vcmeat.com/หน้าแรก"
df.loc[df['เลขทะเบียน'] == "'0275562000651", 'Website'] = "https://www.facebook.com/p/บริษัท-ศรีสุวรรณโภคภัณฑ์-จำกัด-100068298607204"
df.loc[df['เลขทะเบียน'] == "'0735547000837", 'Website'] = "https://www.samphranfarm.com/"
df.loc[df['เลขทะเบียน'] == "'0105556159261", 'Website'] = "https://88foodsdelivery.com/"
df.loc[df['เลขทะเบียน'] == "'0105557160824", 'Website'] = "https://www.nuatair.com/"
df.loc[df['เลขทะเบียน'] == "'0105535063885", 'Website'] = "http://www.itfoods.co.th"
df.loc[df['เลขทะเบียน'] == "'0345534000110", 'Website'] = "https://www.kaona.co.th/"
df.loc[df['เลขทะเบียน'] == "'0135521000011", 'Website'] = "http://www.centaco.com/"
df.loc[df['เลขทะเบียน'] == "'0107537001471", 'Website'] = "www.gfpt.co.th"
df.loc[df['เลขทะเบียน'] == "'0105551130397", 'Website'] = "www.gfn.co.th"
df.loc[df['เลขทะเบียน'] == "'0205538000999", 'Website'] = "chaveevangroup.com"
df.loc[df['เลขทะเบียน'] == "'0105538005967", 'Website'] = "www.sungroup.co.th"
df.loc[df['เลขทะเบียน'] == "'0245544000482", 'Website'] = "www.duckking.co.th"
df.loc[df['เลขทะเบียน'] == "'0107556000493", 'Website'] = "www.br-brgroup.com"
df.loc[df['เลขทะเบียน'] == "'0205560037191", 'Website'] = "www.panuspoultry.co.th"
df.loc[df['เลขทะเบียน'] == "'0925559000916", 'Website'] = "https://www.facebook.com/permpoonfood/"
df.loc[df['เลขทะเบียน'] == "'0655560001362", 'Website'] = "http://www.ppf-group.com"
df.loc[df['เลขทะเบียน'] == "'0705557001127", 'Website'] = "http://pasusart.com"
df.loc[df['เลขทะเบียน'] == "'0705560002023", 'Website'] = "https://www.facebook.com/SFGstarsfoodgroup/"
df.loc[df['เลขทะเบียน'] == "'0905559005268", 'Website'] = "https://lpf.co.th/"
df.loc[df['เลขทะเบียน'] == "'0735546001163", 'Website'] = "https://www.kcf.co.th/"
df.loc[df['เลขทะเบียน'] == "'0305547000199", 'Website'] = "www.puengngeechiang.co.th"
df.loc[df['เลขทะเบียน'] == "'0105547016577", 'Website'] = "https://www.betagro.com/th/home"
df.loc[df['เลขทะเบียน'] == "'0105557051227", 'Website'] = "www.facebook.com/homechefthailand"
df.loc[df['เลขทะเบียน'] == "'0135554005828", 'Website'] = "www.kfpfood.com"
df.loc[df['เลขทะเบียน'] == "'0105525001496", 'Website'] = "https://www.gfpt.co.th/gffoods/"
df.loc[df['เลขทะเบียน'] == "'0105545086497", 'Website'] = "www.chaletfood.co.th"
df.loc[df['เลขทะเบียน'] == "'0105561038639", 'Website'] = "https://www.cpfworldwide.com/th/home"
df.loc[df['เลขทะเบียน'] == "'0105533037836", 'Website'] = "www.tgm.co.th"
df.loc[df['เลขทะเบียน'] == "'0103512000095", 'Website'] = "https://www.belucky.co.th"
df.loc[df['เลขทะเบียน'] == "'0135547001561", 'Website'] = "https://www.facebook.com/p/BM-Quality-Food-Premium-Sausages-Ham-100048531203552/"
df.loc[df['เลขทะเบียน'] == "'0735556002502", 'Website'] = "https://lookchinthip.com/"
df.loc[df['เลขทะเบียน'] == "'0735546002232", 'Website'] = "www.freshmeatfood.com"
df.loc[df['เลขทะเบียน'] == "'0107537001811", 'Website'] = "http://www.sorkon.co.th"
df.loc[df['เลขทะเบียน'] == "'0725549000567", 'Website'] = "https://www.kingbellfood.com/index.html"
df.loc[df['เลขทะเบียน'] == "'0115536000011", 'Website'] = "http://www.thaiunionbone.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105554067971", 'Website'] = "https://www.betagro.com/th/home"
df.loc[df['เลขทะเบียน'] == "'0205540001379", 'Website'] = "http://panuspoultry.co.th"
df.loc[df['เลขทะเบียน'] == "'0115535008744", 'Website'] = "https://www.primaham-thai.com/th/หน้าหลัก/"
df.loc[df['เลขทะเบียน'] == "'0395554000077", 'Website'] = "http://www.pjmeat.com"
df.loc[df['เลขทะเบียน'] == "'0725557000295", 'Website'] = "http://springkitchens.com"
df.loc[df['เลขทะเบียน'] == "'0105560010188", 'Website'] = "https://www.mitsubishicorp.com/th/en/"
df.loc[df['เลขทะเบียน'] == "'0105548012320", 'Website'] = "http://www.globalfish.co.th"
df.loc[df['เลขทะเบียน'] == "'0745521000091", 'Website'] = "http://www.thairoyalfrozen.com/"
df.loc[df['เลขทะเบียน'] == "'0905548000278", 'Website'] = "www.nissui.co.th"
df.loc[df['เลขทะเบียน'] == "'0905527000660", 'Website'] = "http://www.pfp-pacific.com"
df.loc[df['เลขทะเบียน'] == "'0745548002574", 'Website'] = "www.pctuna.co.th"
df.loc[df['เลขทะเบียน'] == "'0745543001278", 'Website'] = "http://www.mrgshrimp.com"
df.loc[df['เลขทะเบียน'] == "'0105532016274", 'Website'] = "https://www.facebook.com/thakamcold/"
df.loc[df['เลขทะเบียน'] == "'0745546001937", 'Website'] = "https://anusorngroup.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105533099441", 'Website'] = "http://www.apfrozen.com"
df.loc[df['เลขทะเบียน'] == "'0925532000095", 'Website'] = "https://www.kantanggroup.com/"
df.loc[df['เลขทะเบียน'] == "'0105558133367", 'Website'] = "www.gambolpet.com"
df.loc[df['เลขทะเบียน'] == "'0745562003574", 'Website'] = "https://www.kgsf.co.th/th/"
df.loc[df['เลขทะเบียน'] == "'0105546088680", 'Website'] = "http://www.seawealth-food.com"
df.loc[df['เลขทะเบียน'] == "'0107537000751", 'Website'] = "www.seafresh.com"
df.loc[df['เลขทะเบียน'] == "'0765539000050", 'Website'] = "https://www.xianningseafood.com/"
df.loc[df['เลขทะเบียน'] == "'0107537001269", 'Website'] = "www.trstrang.com"
df.loc[df['เลขทะเบียน'] == "'0743531000199", 'Website'] = "www.taruamarine.co.th"
df.loc[df['เลขทะเบียน'] == "'0745531000441", 'Website'] = "http://www.tepkinsho.com"
df.loc[df['เลขทะเบียน'] == "'0105532113571", 'Website'] = "https://www.delmar.co.th/th"
df.loc[df['เลขทะเบียน'] == "'0107537001668", 'Website'] = "www.ttimefood.com"
df.loc[df['เลขทะเบียน'] == "'0115525000759", 'Website'] = "http://www.suratseafoods.com/home"
df.loc[df['เลขทะเบียน'] == "'0107537002231", 'Website'] = "www.kst-hatyai.com"
df.loc[df['เลขทะเบียน'] == "'0345560001489", 'Website'] = "https://www.facebook.com/mcwc.ubn/"
df.loc[df['เลขทะเบียน'] == "'0745536001136", 'Website'] = "https://asiansea.co.th/th/"
df.loc[df['เลขทะเบียน'] == "'0905525000425", 'Website'] = "https://www.facebook.com/thaveevongtvh/"
df.loc[df['เลขทะเบียน'] == "'0745528000045", 'Website'] = "https://www.facebook.com/thaveevongtvh/"
df.loc[df['เลขทะเบียน'] == "'0925522000106", 'Website'] = "https://www.kantanggroup.com/index.html"
df.loc[df['เลขทะเบียน'] == "'0107536001061", 'Website'] = "www.asiansea.co.th"
df.loc[df['เลขทะเบียน'] == "'0805550000221", 'Website'] = "www.nsseafood.com"
df.loc[df['เลขทะเบียน'] == "'0905543000342", 'Website'] = "www.s2kmarine.co.th"
df.loc[df['เลขทะเบียน'] == "'0105535010641", 'Website'] = "https://www.facebook.com/haitaifactory/"
df.loc[df['เลขทะเบียน'] == "'0105538119822", 'Website'] = "bpsintertrade.com"
df.loc[df['เลขทะเบียน'] == "'0107537002591", 'Website'] = "https://www.pumpuibrand.co.th/"
df.loc[df['เลขทะเบียน'] == "'0105522010087", 'Website'] = "https://www.patayafood.com/th/"
df.loc[df['เลขทะเบียน'] == "'0107536000757", 'Website'] = "www.seavaluegroup.com/"
df.loc[df['เลขทะเบียน'] == "'0105517008614", 'Website'] = "http://www.threeladycooks.com"
df.loc[df['เลขทะเบียน'] == "'0905548001380", 'Website'] = "www.sif.co.th"
df.loc[df['เลขทะเบียน'] == "'0105523021384", 'Website'] = "https://www.rscannery.com/"
df.loc[df['เลขทะเบียน'] == "'0107548000421", 'Website'] = "http://www.sk-foods.com"
df.loc[df['เลขทะเบียน'] == "'0735542000545", 'Website'] = "https://www.spafoodgroup.com/"
df.loc[df['เลขทะเบียน'] == "'0105547084211", 'Website'] = "https://www.seavaluegroup.com/"
df.loc[df['เลขทะเบียน'] == "'0115529000842", 'Website'] = "http://www.hiqfood.com"
df.loc[df['เลขทะเบียน'] == "'0107537000076", 'Website'] = "www.tropical.co.th"
df.loc[df['เลขทะเบียน'] == "'0945531000041", 'Website'] = "https://pattanifood.co.th/"
df.loc[df['เลขทะเบียน'] == "'0745544000143", 'Website'] = "www.mmptuna.com"
df.loc[df['เลขทะเบียน'] == "'0107536000641", 'Website'] = "www.i-tail.com"
df.loc[df['เลขทะเบียน'] == "'0745543001260", 'Website'] = "www.chocksamut.co.th"
df.loc[df['เลขทะเบียน'] == "'0745554003765", 'Website'] = "https://www.diamondfoodproduct.co.th"
df.loc[df['เลขทะเบียน'] == "'0105532070791", 'Website'] = "www.manafish.com"
df.loc[df['เลขทะเบียน'] == "'0105532104637", 'Website'] = "https://sethachon.com"
df.loc[df['เลขทะเบียน'] == "'0745543001049", 'Website'] = "www.aroymark.com"
df.loc[df['เลขทะเบียน'] == "'0105542094316", 'Website'] = "https://www.nppfoodservice.com/"
df.loc[df['เลขทะเบียน'] == "'0705555001014", 'Website'] = "http://www.eiyoh.co.jp"
df.loc[df['เลขทะเบียน'] == "'0105530024326", 'Website'] = "https://kibunthai.co.th/"
df.loc[df['เลขทะเบียน'] == "'0945545000048", 'Website'] = "http://www.cmr2002.com"
df.loc[df['เลขทะเบียน'] == "'0105532104629", 'Website'] = "www.mfoodshop.com"
df.loc[df['เลขทะเบียน'] == "'0105533075568", 'Website'] = "www.luckyunionfoods.com"
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""
# df.loc[df['เลขทะเบียน'] == "", 'Website'] = ""


# ไม่แน่ใจ = ไม่ใส่

# Index 12
# http://premsukfarmthailand.com/contact

# %%
import webbrowser

lastIndex = "1220" # เริ่ม -1 # Update 'lastIndex' ให้เริ่มค้นหา

for index, row in df.iterrows():
    value1 = row['เลขทะเบียน']
    value2 = row['ชื่อบริษัทภาษาไทย']
    value3 = row['ข้อมูลสำหรับการติดต่อ']
    value4 = row['เบอร์โทร']
    value5 = row['Website']
    value6 = row['ที่ตั้ง']
    value7 = row['ที่มา']
    
    if (index <= int(lastIndex)): continue
#     if (index <= int(lastIndex)): print("You already did:",index, "-", value1, "-", value2, "-", value3, "-", value4); continue
    
    print(f"\n")
    print(f"{index}: {value1} ---{value3} ---{value4} ---{value5} ---{value2}")
    print(f"         {value6}")
    print(f"         {value7}")
    company_search = value2.replace(' ', '+')
    url = f'https://www.google.com/search?q={company_search}+ติดต่อ'
    print(f"         {url}")
#     webbrowser.open(url)
    
    x = input('เบอร์โทร:')
    if x == '-' : break
    df.at[index, 'เบอร์โทร'] = f"'" + x.replace(' ', '').replace('-', '').replace('(', '').replace(')', '').replace('+66', '0')
#     value3 = x.replace(' ', '').str.replace('+66', '0')
#     str = str + f"\n# Index: {index}\nresult.loc[result['ชื่อบริษัทภาษาไทย'] == '{value1}', 'เบอร์โทร'] = '{value3}'\n"
    
#     y = input('Website:')
#     if y == '-' : break
#     df.at[index, 'Website'] = y
#     value4 = y
#     str = str + f"result.loc[result['ชื่อบริษัทภาษาไทย'] == '{value1}', 'Website'] = '{value4}'\n"
    
    lastIndex = index

df.loc[df['เบอร์โทร'] == "'", 'เบอร์โทร'] = np.nan

print(f"\nBreak at Index: {lastIndex}\n")

file_name = 'FilterAndSearchData.csv'
file_path = '/Users/bew/Downloads/DataForThai_jupyter/'

# Combine the file path and file name
full_path = os.path.join(file_path, file_name)

df.to_csv(full_path, sep=',', index=False, header=True, encoding='utf-8')

print('fill done')
# Out:
# 1211: '0745539000912 ---True ---nan ---nan ---บริษัท สตาร์ฟิช จำกัด
#          79/8 หมู่ที่ 1 ตำบลบางโทรัด อำเภอเมืองสมุทรสาคร จ.สมุทรสาคร 74000
#          https://www.dataforthai.com/company/0745539000912/
#          https://www.google.com/search?q=บริษัท+สตาร์ฟิช+จำกัด+ติดต่อ
# เบอร์โทร:0-3483-9935
#
#
# 1212: '0745543001049 ---True ---nan ---nan ---บริษัท สมายล์ ฮาร์ท ฟู้ดส์ จำกัด
#          19/8 หมู่ที่ 8 ตำบลบางกระเจ้า อำเภอเมืองสมุทรสาคร จ.สมุทรสาคร 74000
#          https://www.dataforthai.com/company/0745543001049/
#          https://www.google.com/search?q=บริษัท+สมายล์+ฮาร์ท+ฟู้ดส์+จำกัด+ติดต่อ
# เบอร์โทร:034-869080
#
#
# 1213: '0225554000051 ---True ---nan ---nan ---บริษัท พีเอ็มจี ฟู้ดส์ จำกัด
#          40 หมู่ที่ 9 ตำบลปากน้ำแหลมสิงห์ อำเภอแหลมสิงห์ จ.จันทบุรี 22130
#          https://www.dataforthai.com/company/0225554000051/
#          https://www.google.com/search?q=บริษัท+พีเอ็มจี+ฟู้ดส์+จำกัด+ติดต่อ
# เบอร์โทร:039-317307
#
#
# ...

# %%
# print("Update file data test_fill to test")

# file_update = 'test.csv'
# file_path = '/Users/bew/Downloads/'

# # Combine the file path and file name
# full_path = os.path.join(file_path, file_update)

# df.to_csv(full_path, sep=',', index=False, header=True, encoding='utf-8')

# print("Finish Update")
