# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import os
import json
from pandas import json_normalize
# pd.__version__

# %%
topic_file = '/Users/bew/Downloads/DataForThai_Pandas&SubTopic/SubTopic_dataforthai.csv'
topic_table = pd.read_csv(topic_file)


topic_table['รหัส'] = topic_table['รหัส'].astype(str)
# Function to add '0' to strings of length 4
def add_zero(s):
    if len(s) == 4:
        return '0' + s
    else:
        return s
# Applying the function to the DataFrame
topic_table['รหัส'] = topic_table['รหัส'].apply(lambda x: add_zero(x))


# topic_table.dtypes
topic_table = topic_table[:20]
# topic_table = topic_table[topic_table['รหัส']=='01450']
# print(topic_table)
# max(topic_table['จำนวนหน้า'])
topic_table
# Out:
#      รหัส                                       ประเภทธุรกิจ  จำนวน  จำนวนหน้า
# 0   01111                       การปลูกข้าวโพดที่ใช้เมล็ดแก่     24          1
# 1   01112               การปลูกธัญพืช (ยกเว้นข้าวและข้าวโพด)     34          1
# 2   01113                               การปลูกพืชตระกูลถั่ว     15          1
# 3   01114                                  การปลูกถั่วเหลือง      3          1
# 4   01115                การปลูกพืชน้ำมัน (ยกเว้นถั่วเหลือง)     10          1
# 5   01121                                    การปลูกข้าวจ้าว    640          2
# 6   01122                                  การปลูกข้าวเหนียว    374          1
# 7   01131  การปลูกพืชผักกินใบและพืชผักกินต้น รวมถึงการเพา...    134          1
# 8   01132  การปลูกพืชผักกินผลรวมถึงแตงชนิดต่าง ๆ รวมถึงกา...     48          1
# 9   01133                                การปลูกพืชผักกินหัว      9          1
# 10  01135                                 การปลูกมันสำปะหลัง     84          1
# 11  01136                                        การเพาะเห็ด     98          1
# 12  01139  การปลูกพืชผักอื่นๆ ซึ่งมิได้จัดประเภทไว้ในที่อื่น    307          1
# 13  01140                                        การปลูกอ้อย     74          1
# 14  01150                                       การปลูกยาสูบ      5          1
# 15  01161                                        การปลูกฝ้าย      1          1
# 16  01169  การปลูกพืชเส้นใยอื่นๆ ซึ่งมิได้จัดประเภทไว้ในท...      5          1
# 17  01191                          การปลูกข้าวโพดเลี้ยงสัตว์     30          1
# 18  01192  การปลูกพืชล้มลุกที่ใช้เป็นอาหารสัตว์ (ยกเว้นข้...     10          1
# 19  01193                                    การปลูกกล้วยไม้     28          1

# %%
# topic_for_file = topic_table[topic_table['รหัส'] == no_topic]
# topic_for_file

# %%
# # Read JSON file
# file_path = f'/Users/bew/Downloads/WebScrapperFor_DataForThai/Target/01111.json'  # Replace with your file path

# df = pd.read_json(file_path)

# # # Load JSON data into DataFrame
# # df = json_normalize(json_data)  # Use pd.DataFrame(json_data) if the JSON is already flat

# # df['สถานะ'] = df['สถานะ'].astype("string")
# df.dtypes
# # df

# %%
import pandas as pd
import os

# Initialize an empty DataFrame for the result
result = pd.DataFrame()

for index, row in topic_table.iterrows():
    
    value1 = row['รหัส']
    value2 = row['ประเภทธุรกิจ']
    
    # Construct the file path
    file_path = f'/Users/bew/Downloads/WebScrapperFor_DataForThai/Target/{value1}.json'
    
    # Check if the file exists
    if os.path.exists(file_path):
        try:
            # Read JSON file
            df = pd.read_json(file_path)
            
            # Add a new column with the business type
#             df['ประกอบธุรกิจ'] = value2
            
            # Concatenate the current DataFrame to the result DataFrame
            result = pd.concat([result, df], axis=0)
        
        except ValueError as e:
            print(f"Error reading JSON file at {file_path}: {e}")
    else:
        print(f"File not found: {file_path}")
# Out:
# File not found: /Users/bew/Downloads/WebScrapperFor_DataForThai/Target/01114.json
# File not found: /Users/bew/Downloads/WebScrapperFor_DataForThai/Target/01122.json
# File not found: /Users/bew/Downloads/WebScrapperFor_DataForThai/Target/01133.json
# File not found: /Users/bew/Downloads/WebScrapperFor_DataForThai/Target/01150.json
# File not found: /Users/bew/Downloads/WebScrapperFor_DataForThai/Target/01161.json
# File not found: /Users/bew/Downloads/WebScrapperFor_DataForThai/Target/01169.json

# %%
# Reset the index of the final result DataFrame
result = result.reset_index(drop=True)

# result

# %%
result.columns.tolist()

result['เบอร์โทร'] = np.nan
new_order = ['เลขทะเบียน', 'ชื่อบริษัทภาษาไทย', 'ชื่อบริษัทภาษาอังกฤษ', 'ประกอบธุรกิจ', 'หมวดธุรกิจ', 'สถานะ',
             'วันที่จดทะเบียน', 'ทุนจดทะเบียน', 'ที่ตั้ง', 'ข้อมูลสำหรับการติดต่อ', 'เบอร์โทร', 'Website', 'ก่อตั้งโดย',
             'หลักทรัพย์', 'ที่มา', 'สมัครงาน / ดูตำแหน่งงานว่าง', 'วันที่ร้าง', 'วันที่เลิก']
result = result[new_order]
# result

# %%
# for index, row in topic_table.iterrows():
    
#     value1 = row['รหัส']
#     value2 = row['ประเภทธุรกิจ']
    
#     # Read JSON file
#     file_path = f'/Users/bew/Downloads/WebScrapperFor_DataForThai/Target/{value1}.json'  # Replace with your file path

#     df = pd.read_json(file_path)
    
#     df['ประกอบธุรกิจ'] = value2
    
#     result = pd.concat([result, df], axis=0)
    
    
# result

# %%
# result = result.drop(columns=['สมัครงาน / ดูตำแหน่งงานว่าง', 'วันที่ร้าง', 'หลักทรัพย์'])

result = result.applymap(str)
# result['เลขทะเบียน'] = result['เลขทะเบียน'].map(str)
# result['สถานะ'] = result['สถานะ'].astype("string")


# Step 1: Remove commas from the strings
result['ทุนจดทะเบียน'] = result['ทุนจดทะเบียน'].str.replace(',', '')
result['ทุนจดทะเบียน'] = result['ทุนจดทะเบียน'].str.replace(' บาท', '')
# Step 2: Convert the strings to numeric type (int or float)
result['ทุนจดทะเบียน'] = pd.to_numeric(result['ทุนจดทะเบียน'])

result.dtypes
# Out:
# เลขทะเบียน                     object
# ชื่อบริษัทภาษาไทย              object
# ชื่อบริษัทภาษาอังกฤษ           object
# ประกอบธุรกิจ                   object
# หมวดธุรกิจ                     object
# สถานะ                          object
# วันที่จดทะเบียน                object
# ทุนจดทะเบียน                    int64
# ที่ตั้ง                        object
# ข้อมูลสำหรับการติดต่อ          object
# เบอร์โทร                       object
# Website                        object
# ก่อตั้งโดย                     object
# หลักทรัพย์                     object
# ที่มา                          object
# สมัครงาน / ดูตำแหน่งงานว่าง    object
# วันที่ร้าง                     object
# วันที่เลิก                     object
# dtype: object

# %%
result = result[result['สถานะ']=='ยังดำเนินกิจการอยู่']
result = result[(result['ทุนจดทะเบียน'] >= 30000000)]

# def get_length(obj):
#     try:
#         return len(obj)
#     except TypeError:
#         return None

# for text in result['ทุนจดทะเบียน']:
#     print(text.apply(get_length))

# for index, row in result.iterrows():
    
#     value1 = row['เลขทะเบียน']
#     if value1.apply(len) != 13:
#         value1 = "0" + value1.astype(str)

result['เลขทะเบียน'] = "0" + result['เลขทะเบียน'].astype(str)
# # Function to add '0' to strings of length 13
# def add_zero(s):
# #     s = str(s)  # Ensure the input is a string
#     if len(s) == 14:
#         return '0' + s
#     else:
#         return s

# # Applying the function to the DataFrame
# result['เลขทะเบียน'] = result['เลขทะเบียน'].apply(lambda x: add_zero(x))

# # Reset the index of the final result DataFrame
# result = result.reset_index(drop=True)

# result.dtypes

# %%
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' มกราคม ','/1/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' กุมภาพันธ์ ','/2/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' มีนาคม ','/3/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' เมษายน ','/4/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' พฤษภาคม ','/5/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' มิถุนายน ','/6/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' กรกฎาคม ','/7/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' สิงหาคม ','/8/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' กันยายน ','/9/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' ตุลาคม ','/10/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' พฤศจิกายน ','/11/')
result['วันที่จดทะเบียน'] = result['วันที่จดทะเบียน'].str.replace(' ธันวาคม ','/12/')

# %%
result = result.reset_index(drop=True)
result
# Out:
#        เลขทะเบียน                         ชื่อบริษัทภาษาไทย  \
# 0   0105523007276  บริษัท ไพโอเนีย ไฮ-เบรด (ไทยแลนด์) จำกัด
# 1   0105539070673              บริษัท ซาคาตะ สยาม ซีด จำกัด
# 2   0105563169226              บริษัท ทรัพย์ในดิน 666 จำกัด
# 3   0815524000023                 บริษัท ไพรสณฑ์ปาล์ม จำกัด
# 4   0105531018826                บริษัท สหปาล์ม ออยล์ จำกัด
# ..            ...                                       ...
# 56  0105548129332            บริษัท ทีโอแอล เทคโนโลยี จำกัด
# 57  0205560039819     บริษัท ศุภชาติ แพลนท์ เนอสเซอรี จำกัด
# 58  0105539082124              บริษัท สหวิริยาออร์คิด จำกัด
# 59  0105554129691              บริษัท สุพรีม โฟร์ไลฟ์ จำกัด
# 60  0105529045129            บริษัท เอ็กซ์เซล ออร์คิด จำกัด
#
#                        ชื่อบริษัทภาษาอังกฤษ  \
# 0      PIONEER HI-BRED (THAILAND) CO., LTD.
# 1                SAKATA SIAM SEED CO., LTD.
# 2             SUBNAIDIN 666 COMPANY LIMITED
# 3
# 4              MORI FOOD PRODUCTS CO., LTD.
# ..                                      ...
# 56       T O L TECHNOLOGIES COMPANY LIMITED
# 57  SUPHACHAT PLANT NURSERY COMPANY LIMITED
# 58        SAHAVIRIYA ORCHID COMPANY LIMITED
# 59                  SUPREME 4LIFE CO., LTD.
# 60             EXCEL ORCHID COMPANY LIMITED
#
#                                          ประกอบธุรกิจ  \
# 0   ผลิตเมล็ดพันธุ์ข้าวโพดและข้าวฟ่าง จำหน่ายเมล็ด...
# 1                                  จำหน่ายเมล็ดพันธุ์
# 2                       เพาะปลูกผลิตผลทางการเกษตรกรรม
# 3                               ประกอบกิจการเกษตรกรรม
# 4                 การเกษตรกรรมทุกชนิด และการให้บริการ
# ..                                                ...
# 56  สั่งเข้า ส่งออก ปลูก ประดิษฐ์ ดัดแปลง รับจัด จ...
# 57
# 58                          เพาะและขยายพันธุ์กล้วยไม้
# 59  ผลิต เพาะพันธุ์ ขยายพันธุ์ นำเข้าและส่งออกกล้ว...
# 60  ส่งออกดอกกล้วยไม้ผลิตดอกกล้วยไม้และรับจ้างบรรจ...
#
#                               หมวดธุรกิจ                สถานะ วันที่จดทะเบียน  \
# 0           การปลูกข้าวโพดที่ใช้เมล็ดแก่  ยังดำเนินกิจการอยู่       29/4/2523
# 1   การปลูกธัญพืช (ยกเว้นข้าวและข้าวโพด)  ยังดำเนินกิจการอยู่       26/6/2539
# 2                        การปลูกข้าวจ้าว  ยังดำเนินกิจการอยู่      17/11/2563
# 3   การปลูกธัญพืช (ยกเว้นข้าวและข้าวโพด)  ยังดำเนินกิจการอยู่       17/9/2524
# 4   การปลูกธัญพืช (ยกเว้นข้าวและข้าวโพด)  ยังดำเนินกิจการอยู่       16/3/2531
# ..                                   ...                  ...             ...
# 56                       การปลูกกล้วยไม้  ยังดำเนินกิจการอยู่       30/9/2548
# 57                       การปลูกกล้วยไม้  ยังดำเนินกิจการอยู่       4/12/2560
# 58                       การปลูกกล้วยไม้  ยังดำเนินกิจการอยู่       23/7/2539
# 59                       การปลูกกล้วยไม้  ยังดำเนินกิจการอยู่       28/9/2554
# 60                       การปลูกกล้วยไม้  ยังดำเนินกิจการอยู่       9/12/2529
#
#     ทุนจดทะเบียน                                            ที่ตั้ง  \
# 0      245000000  87 อาคารเอ็ม.ไทย ทาวเวอร์ ออลซีซันส์ เพลส ชั้น...
# 1      162000000  260 หมู่ที่ 13 ตำบลโนนท่อน อำเภอเมืองขอนแก่น จ...
# 2      100000000  71 อาคารเอจีอาร์ ชั้นที่ 4 ถนนเจริญราษฎร์ แขวง...
# 3       30000000  141 หมู่ที่ 2 ถนนเพชรเกษม ตำบลอ่าวลึกเหนือ อำเ...
# 4      150000000  109 หมู่ที่ 9 ถนนสุวรรณศร ตำบลดงขี้เหล็ก อำเภอ...
# ..           ...                                                ...
# 56      80000000  172 ซอยรามอินทรา 67 แยก 6 แขวงรามอินทรา เขตคัน...
# 57      73000000  29/11 หมู่ที่ 11 ตำบลบางพระ อำเภอศรีราชา จ.ชลบ...
# 58      37500000  28/1 อาคารประภาวิทย์ ชั้น 8 ถนนสุรศักดิ์ แขวงส...
# 59      50000000  92/5-7 หมู่ที่ 6 ตำบลราษฎร์นิยม อำเภอไทรน้อย จ...
# 60     100000000  1499 ซอยเพชรเกษม 63 แขวงหลักสอง เขตบางแค กรุงเ...
#
#    ข้อมูลสำหรับการติดต่อ เบอร์โทร Website  \
# 0                  False      nan     nan
# 1                  False      nan     nan
# 2                  False      nan     nan
# 3                  False      nan     nan
# 4                  False      nan     nan
# ..                   ...      ...     ...
# 56                 False      nan     nan
# 57                 False      nan     nan
# 58                 False      nan     nan
# 59                 False      nan     nan
# 60                 False      nan     nan
#
#                                            ก่อตั้งโดย หลักทรัพย์  \
# 0   กรรมการ: นายกิตติพงษ์ ลิมปสุรัติ, นางจริยา วุฒ...        nan
# 1   กรรมการ: นายโยชิฮิโร โอบาทาเกะ, นายเซน ทากามิย...        nan
# 2                        กรรมการ: นางสาวอรวรรณ พัฒนพล        nan
# 3   กรรมการ: นายบุญส่ง ลีลามั่นคง, นางสุรัตน์ โพธิ...        nan
# 4   กรรมการ: นางสาววรรณี จันทร์ไกรวัล, นางณัฐนี ตุ...        nan
# ..                                                ...        ...
# 56  กรรมการ: พลตำรวจเอกชวลิต ยอดมณี, นายไพบูลย์ กว...        nan
# 57                    กรรมการ: นางกาญจนา เขมะคงคานนท์        nan
# 58  กรรมการ: นายสมประสานต์ ทรัพย์สิริไพศาล, นายวิท...        nan
# 59                        กรรมการ: นายเกรียง กาญจนวตี        nan
# 60  กรรมการ: นายทิพากร แสงอุทัย, นางอัศนี แสงอุทัย...        nan
#
#                                                 ที่มา  \
# 0   https://www.dataforthai.com/company/0105523007...
# 1   https://www.dataforthai.com/company/0105539070...
# 2   https://www.dataforthai.com/company/0105563169...
# 3   https://www.dataforthai.com/company/0815524000...
# 4   https://www.dataforthai.com/company/0105531018...
# ..                                                ...
# 56  https://www.dataforthai.com/company/0105548129...
# 57  https://www.dataforthai.com/company/0205560039...
# 58  https://www.dataforthai.com/company/0105539082...
# 59  https://www.dataforthai.com/company/0105554129...
# 60  https://www.dataforthai.com/company/0105529045...
#
#    สมัครงาน / ดูตำแหน่งงานว่าง วันที่ร้าง วันที่เลิก
# 0    ดูตำแหน่งงานจาก JOBTOPGUN        nan        nan
# 1                          nan        nan        nan
# 2                          nan        nan        nan
# 3                          nan        nan        nan
# 4                          nan        nan        nan
# ..                         ...        ...        ...
# 56                         nan        nan        nan
# 57                         nan        nan        nan
# 58                         nan        nan        nan
# 59                         nan        nan        nan
# 60                         nan        nan        nan
#
# [61 rows x 18 columns]

# %%
result.dtypes
# Out:
# เลขทะเบียน                     object
# ชื่อบริษัทภาษาไทย              object
# ชื่อบริษัทภาษาอังกฤษ           object
# ประกอบธุรกิจ                   object
# หมวดธุรกิจ                     object
# สถานะ                          object
# วันที่จดทะเบียน                object
# ทุนจดทะเบียน                    int64
# ที่ตั้ง                        object
# ข้อมูลสำหรับการติดต่อ          object
# เบอร์โทร                       object
# Website                        object
# ก่อตั้งโดย                     object
# หลักทรัพย์                     object
# ที่มา                          object
# สมัครงาน / ดูตำแหน่งงานว่าง    object
# วันที่ร้าง                     object
# วันที่เลิก                     object
# dtype: object

# %%
file1 = '/Users/bew/Downloads/test.csv'
df1 = pd.read_csv(file1)

# แปลง int64 เป็น object
df1['เลขทะเบียน'] = "0" + df1['เลขทะเบียน'].astype(str)
# สามารถใช้ apply() เพื่อแปลงทุกคอลัมน์ที่มี float64 เป็น object ได้
df1 = df1.apply(lambda x: x.astype('object') if x.dtype == 'float64' else x)


# df = df.drop(columns=['ประกอบธุรกิจ', 'หมวดธุรกิจ', 'สถานะ', 'วันที่จดทะเบียน', 'ทุนจดทะเบียน', 'ที่ตั้ง', 'ก่อตั้งโดย','หลักทรัพย์', 'สมัครงาน / ดูตำแหน่งงานว่าง', 'วันที่ร้าง', 'วันที่เลิก'])

df1
# df1.dtypes
# Out:
#        เลขทะเบียน                            ชื่อบริษัทภาษาไทย  \
# 0   0105523007276     บริษัท ไพโอเนีย ไฮ-เบรด (ไทยแลนด์) จำกัด
# 1   0105539070673                 บริษัท ซาคาตะ สยาม ซีด จำกัด
# 2   0105563169226                 บริษัท ทรัพย์ในดิน 666 จำกัด
# 3   0815524000023                    บริษัท ไพรสณฑ์ปาล์ม จำกัด
# 4   0105531018826                   บริษัท สหปาล์ม ออยล์ จำกัด
# 5   0575554001772            บริษัท อนันต์ทรัพย์เพิ่มทวี จำกัด
# 47                    PRESERVE AGRO PRODUCTS CO.,LTD.
# 48                              PACCAN GROW CO., LTD.
# 49                         MID-SIAM CAPITAL CO., LTD.
# 50                        VIBUL SUGAR COMPANY LIMITED
# 51                            RAI DAN CHANG CO., LTD.
# 52               AREE AGRICULTURAL BUSINESS CO., LTD.
#
#                                          ประกอบธุรกิจ  \
# 0   ผลิตเมล็ดพันธุ์ข้าวโพดและข้าวฟ่าง จำหน่ายเมล็ด...
# 1                                  จำหน่ายเมล็ดพันธุ์
# 2                       เพาะปลูกผลิตผลทางการเกษตรกรรม
# 3                               ประกอบกิจการเกษตรกรรม
# 4                 การเกษตรกรรมทุกชนิด และการให้บริการ
# 5                                       การปลูกธัญพืช
# 6                              การปลูกพืชที่ให้น้ำมัน
# 7                                            สวนปาล์ม
# 8                                 การปลูกพืชให้น้ำมัน
# 9   การทำนา ทำสวน ทำไร่ เลี้ยงสัตว์และกิจการคอกปศุ...
# 10                       ประกอบกิจการทำนา ทำสวน ทำไร่
# 11                        กิจกรรมสนับสนุนการผลิตพืชผล
# 12  ทำนา ทำสวน ทำไร่ เลี้ยงสัตว์และกิจการคอกปศุสัต...
# 13                                    การปลูกข้าวเจ้า
# 14          การปลูกข้าวจ้าว การเกษตร ทำนาข้าวเพื่อขาย
# 15                               สวนเกษตร และ รีสอร์ท
# 16                                                NaN
# 17                              ผลิตรองเท้าและกระเป๋า
# 18                            การทำฟาร์มผักปลอดสารพิษ
# 19  การซื้อและการขายอสังหาริมทรัพย์ที่เป็นของตนเอง...
# 20                                         ทำการเกษตร
# 21                                                NaN
# 22                            ประกอบกิจการลงทุนทั่วไป
# 23            ประกอบกิจการเพาะเลี้ยงกุ้งเพื่อการเกษตร
# 24                                      ให้เช่าที่ดิน
# 25                        ประกอบกิจการปลูกพืชผักกินผล
# 26                  ให้เช่า ซื้อและขายอสังหาริมทรัพย์
# 27  การปลูกพืชผักกินผลรวมถึงแตงชนิดต่างๆ รวมถึงการ...
# 28                                     ให้เช่าพื้นที่
# 29                             ปลูกมันสำปะหลังจำหน่าย
# 30                                    ปลูกมันสำปะหลัง
# 31                                                NaN
# 32                          กสิกรรม ปลูกมันและข้าวโพด
# 33                         ปลูกพืชการเกษตรมันสำปะหลัง
# 34                                                NaN
# 35              ประกอบธุรกิจปลูกและจำหน่ายมันสำปะหลัง
# 36                                                NaN
# 37                ผลิตและจำหน่ายเห็ดออรินจิ ฟาร์มเห็ด
# 38                                                NaN
# 39                                    ผลิตจำหน่ายเห็ด
# 40                                                NaN
# 41                          ผลิตและจำหน่ายเห็ดเข็มทอง
# 42                                                NaN
# 43  ประกอบกิจการธุรกิจเกี่ยวกับการเกษตร เกษตรกรรม ...
# 44                                                NaN
# 45                                        พืชผักผลไม้
# 46                                                NaN
# 47  ประกอบกิจการค้า ผลิต จำหน่าย ผักผลไม้ ทั้งสดแล...
# 48  การเกษตร เพาะปลูกพืชและสมุนไพรทุกชนิด การทำเกษ...
# 49  ปลูกอ้อย-การทำไร่อ้อยและพืชที่ให้ความหวานลงทุน...
# 50                                       ขายพืชชีวมวล
# 51                                           ปลูกอ้อย
# 52                                           ปลูกอ้อย
#
#                                            หมวดธุรกิจ                สถานะ  \
# 0                        การปลูกข้าวโพดที่ใช้เมล็ดแก่  ยังดำเนินกิจการอยู่
# 1                การปลูกธัญพืช (ยกเว้นข้าวและข้าวโพด)  ยังดำเนินกิจการอยู
การปลูกพืชผักอื่นๆ ซึ่งมิได้จัดประเภทไว้ในที่อื่น  ยังดำเนินกิจการอยู่
# 46  การซื้อและการขายอสังหาริมทรัพย์ที่เป็นของตนเอง...  ยังดำเนินกิจการอยู่
# 47  การปลูกพืชผักอื่นๆ ซึ่งมิได้จัดประเภทไว้ในที่อื่น  ยังดำเนินกิจการอยู่
# 48  การปลูกพืชผักอื่นๆ ซึ่งมิได้จัดประเภทไว้ในที่อื่น  ยังดำเนินกิจการอยู่
# 49                                        การปลูกอ้อย  ยังดำเนินกิจการอยู่
# 50                                        การปลูกอ้อย  ยังดำเนินกิจการอยู่
# 51                                        การปลูกอ้อย  ยังดำเนินกิจการอยู่
# 52                                        การปลูกอ้อย  ยังดำเนินกิจการอยู่
#
#    วันที่จดทะเบียน  ทุนจดทะเบียน  \
# 0        29/4/2523     245000000
# 1        26/6/2539     162000000
# 2       17/11/2563     100000000
# 3        17/9/2524      30000000
# 4        16/3/2531     150000000
# 5       24/11/2554      36000000
# 6         4/7/2531     104000000
# 7         3/5/2521      35000000
# 8        12/6/2555     170000000
# 9         5/7/2554      60000000
# 10       16/1/2563      50000000
# 11        8/7/2563     260000000
# 12        1/2/2556     100000000
# 13      19/10/2559      51000000
# 14        4/8/2563      50000000
# 15       21/8/2544     300000000
# 16       20/3/2561      39900000
# 17       12/5/2537     275400000
# 18      14/10/2547     290000000
# 19       26/3/2535      30000000
# 20      17/10/2562      35000000
# 21      23/11/2563     150000000
# 22      10/10/2560     160000000
# 23       11/3/2565      40000000
# 24        8/7/2563      55000000
# 25        7/2/2563      40000000
# 26        2/6/2538      33000000
# 27       22/4/2565    1000000000
# 28       22/8/2533      55000000
# 29       27/4/2560      31000000
# 30        1/6/2549     150000000
# 31        4/7/2538     380000000
# 32       9/10/2552      36000000
# 33        4/8/2547     540000000
# 34        4/4/2534      60000000
# 35        8/8/2551      70000000
# 36       20/4/2549      41000000
# 37       1/10/2545      30000000
# 38       30/9/2552     800000000
# 39       24/8/2555      52000000
# 40      18/12/2561      61900000
# 41       1/10/2535     100000000
# 42       19/7/2565      40000000
# 43       3/12/2562     120000000
# 44       18/8/2559    2862000000
# 45        5/1/2526      50000000
# 46      13/12/2560     169720000
# 47       18/5/2552     115000000
# 48        3/2/2565      35000000
# 49        8/6/2526     120000000
# 50       24/9/2551      50000000
# 51       23/3/2544      60000000
# 52      11/10/2534      90000000
#
#                                               ที่ตั้ง  ข้อมูลสำหรับการติดต่อ  \
# 0   87 อาคารเอ็ม.ไทย ทาวเวอร์ ออลซีซันส์ เพลส ชั้น...                  False
# 1   260 หมู่ที่ 13 ตำบลโนนท่อน อำเภอเมืองขอนแก่น จ...                  False
# 2   71 อาคารเอจีอาร์ ชั้นที่ 4 ถนนเจริญราษฎร์ แขวง...                  False
# 3   141 หมู่ที่ 2 ถนนเพชรเกษม ตำบลอ่าวลึกเหนือ อำเ...                  False
# 4   109 หมู่ที่ 9 ถนนสุวรรณศร ตำบลดงขี้เหล็ก อำเภอ...                  False
# 5   450/23 หมู่ที่ 6 ตำบลริมกก อำเภอเมืองเชียงราย ...                  False
# 6   97/1 หมู่ที่ 8 ตำบลป่าคลอก อำเภอถลาง จ.ภูเก็ต ...                  False
# 7   20/5 อาคารวงศ์บัณฑิต ห้องเลขที่ 2 บี ถนนโกมารภ...                  False
# 8   194/16 ซอยภิรมย์ ถนนทรงวาด แขวงจักรวรรดิ เขตสั...                  False
# 9   4188/1 ถนนดินแดง แขวงดินแดง เขตดินแดง กรุงเทพม...                  False
# 10  91/86 หมู่บ้าน พาทิโอ หมู่ที่ 5 ตำบลบ้านใหม่ อ...                  False
# 11  81/1 ซอยเพชรเกษม 54 แยก 3 แขวงบางด้วน เขตภาษีเ...                  False
# 12  168 หมู่ที่ 9 ซอยแบริ่ง 31 ถนนสุขุมวิท ตำบลสำโ...                  False
# 13  95/66 หมู่บ้านกรีนวัลเลย์ หมู่ที่ 3 ถนนบางนา-ต...                  False
# 14  99/192 หมู่ที่ 6 ตำบลพันท้ายนรสิงห์ อำเภอเมือง...                  False
# 15  14 ซอยงามวงศ์วาน 8 ถนนงามวงศ์วาน ตำบลบางเขน อำ...                  False
# 16  2 ซอยพรีเมียร์ 1 ถนนศรีนครินทร์ แขวงหนองบอน เข...                  False
# 17  620/5 หมู่ที่ 11 ตำบลหนองขาม อำเภอศรีราชา จ.ชล...                  False
# 18  8/39 อาคารเคเค ซิตี้ หมู่ที่ 9 ถนนบางบัวทอง-สุ...                  False
# 19  133/21-37 หมู่ที่ 7 ถนนสุขุมวิท ตำบลบางปูใหม่ ...                  False
# 20  66/62 หมู่ที่ 3 ตำบลบ้านฉาง อำเภอเมืองปทุมธานี...                  False
# 21  899 หมู่ที่ 2 ตำบลท้ายบ้านใหม่ อำเภอเมืองสมุทร...                  False
# 22  40/1 ห้องดี หมู่ที่ 12 ซอยหลวงแพ่ง 8 ถนนหลวงแพ...                  False
# 23  61/1 หมู่ที่ 6 ตำบลราชาเทวะ อำเภอบางพลี จ.สมุท...                  False
# 24  545 หมู่ที่ 8 ถนนเหล่านาดี ตำบลเมืองเก่า อำเภอ...                  False
# 25  177 หมู่ที่ 2 ตำบลออนเหนือ อำเภอแม่ออน จ.เชียง...                  False
# 26  27 ซอยปุณณวิถี 29/1 แขวงบางจาก เขตพระโขนง กรุง...                  False
# 27  16/21 ซอย อ่อนนุช 74/1 แขวงประเวศ เขตประเวศ กร...                  False
# 28  603 ถนนประชาอุทิศ แขวงวังทองหลาง เขตวังทองหลาง...                  False
# 29  89 หมู่ที่ 5 ตำบลครึ่ง อำเภอเชียงของ จ.เชียงรา...                  False
# 30  888 อาคารไอทาวเวอร์ ชั้น 30 ถนนวิภาวดีรังสิต แ...                  False
# 31  888 อาคารไอทาวเวอร์ ชั้นที่ 8 ถนนวิภาวดีรังสิต...                  False
# 32  19 หมู่ที่ 1 ตำบลลาดสวาย อำเภอลำลูกกา จ.ปทุมธา...                  False
# 33  888 อาคารไอทาวเวอร์ ชั้นที่ 8 แขวงจตุจักร เขตจ...                  False
# 34  23 อาคารสรชัย ซอยสุขุมวิท 63 (เอกมัย) ถนนสุขุม...                  False
# 35  160/833 อาคารไอทีเอฟ-สีลมพาเลส ชั้น 32 ถนนสีลม...                  False
# 36  29 หมู่ที่ 14 ถนนเชียงใหม่-พร้าว ตำบลแม่แฝกใหม...                  False
# 37  150/2 หมู่ที่ 3 หมู่บ้านหน้าวัดเขามัน ตำบลทับก...                  False
# 38  470 ถนนบางขุนเทียนชายทะเล แขวงแสมดำ เขตบางขุนเ...                  False
# 39   91 หมู่ที่ 5 ตำบลเนินฆ้อ อำเภอแกลง จ.ระยอง 21110                  False
# 40  105/1 หมู่ที่ 3 ตำบลหนองช้างแล่น อำเภอห้วยยอด ...                  False
# 41  224 หมู่ที่ 14 ตำบลแม่แฝกใหม่ อำเภอสันทราย จ.เ...                  False
# 42  96/21 หมู่ที่ 8 ตำบลเกาะขวาง อำเภอเมืองจันทบุร...                  False
# 43  78/80 ซอยประเสริฐมนูกิจ 29 แยก 2 ถนนประเสริฐมน...                  False
# 44  1/97-98 ซอยพหลโยธิน 40 ถนนพหลโยธิน แขวงเสนานิค...                  False
# 45  118/1 ถนนพระราม 6 แขวงพญาไท เขตพญาไท กรุงเทพมห...                  False
# 46  105 ซอยประสาทสุข ถนนเย็นอากาศ แขวงช่องนนทรี เข...                  False
# 47  213 หมู่ที่ 2 ตำบลขี้เหล็ก อำเภอแม่ริม จ.เชียง...                  False
# 48  59 ถนนสตรีวิทยา 2 แขวงลาดพร้าว เขตลาดพร้าว กรุ...                  False
# 49  99 หมู่ที่ 10 ตำบลโคกสะอาด อำเภอภูเขียว จ.ชัยภ...                  False
# 50  408/159 อาคารพหลโยธิน เพลส ชั้น 38 ถนนพหลโยธิน...                  False
# 51  99 หมู่ที่ 5 ตำบลด่านช้าง อำเภอด่านช้าง จ.สุพร...                  False
# 52  43 อาคารไทย ซีซี ทาวเวอร์ ชั้น 28 ถนนสาทรใต้ แ...                  False
#
#       เบอร์โทร                                Website  \
# 0   27922900.0                                    NaN
# 1   43001314.0                                    NaN
# 2          NaN                                    NaN
# 3   75681136.0                                    NaN
# 4          NaN                                    NaN
# 5          NaN                                    NaN
# 6   22780899.0                                    NaN
# 7          NaN                                    NaN
# 8          NaN                                    NaN
# 9          NaN                                    NaN
# 10         NaN                                    NaN
# 11         NaN                                    NaN
# 12         NaN                                    NaN
# 13         NaN                                    NaN
# 14         NaN                                    NaN
# 15         NaN                                    NaN
# 16         NaN  https://www.facebook.com/naateesaeng/
# 17         NaN         http://www.panasiafootwear.com
# 18         NaN                                    NaN
# 19         NaN                                    NaN
# 20         NaN                                    NaN
# 21         NaN                                    NaN
# 22         NaN                                    NaN
# 23         NaN                                    NaN
# 24         NaN                                    NaN
# 25         NaN                                    NaN
# 26         NaN                                    NaN
# 27         NaN                                    NaN
# 28         NaN                                    NaN
# 29         NaN                                    NaN
# 30         NaN                                    NaN
# 31         NaN                                    NaN
# 32         NaN                                    NaN
# 33         NaN                    eternalenergy.co.th
# 34         NaN                                    NaN
# 35         NaN                                    NaN
# 36         NaN                                    NaN
# 37         NaN                                    NaN
# 38         NaN         www.facebook.com/promushroomth
# 10  https://www.dataforthai.com/company/0125563001...
# 11  https://www.dataforthai.com/company/0105563099...
# 12  https://www.dataforthai.com/company/0115556002...
# 13  https://www.dataforthai.com/company/0115559022...
# 14  https://www.dataforthai.com/company/0745563006...
# 15  https://www.dataforthai.com/company/0125544007...
# 16  https://www.dataforthai.com/company/0105561050...
# 17  https://www.dataforthai.com/company/0107537001...
# 18  https://www.dataforthai.com/company/0105547140...
# 19  https://www.dataforthai.com/company/0105535054...
# 20  https://www.dataforthai.com/company/0115562027...
# 21  https://www.dataforthai.com/company/0115563024...
# 22  https://www.dataforthai.com/company/0115560024...
# 23  https://www.dataforthai.com/company/0115565007...
# 24  https://www.dataforthai.com/company/0405563002...
# 25  https://www.dataforthai.com/company/0505563002...
# 26  https://www.dataforthai.com/company/0105538066...
# 27  https://www.dataforthai.com/company/0105565068...
# 28  https://www.dataforthai.com/company/0105533100...
# 29  https://www.dataforthai.com/company/0105560070...
# 30  https://www.dataforthai.com/company/0105549067...
# 31  https://www.dataforthai.com/company/0105538078...
# 32  https://www.dataforthai.com/company/0135552009...
# 33  https://www.dataforthai.com/company/0115547008...
# 34  https://www.dataforthai.com/company/0105534032...
# 35  https://www.dataforthai.com/company/0105551089...
# 36  https://www.dataforthai.com/company/0505549002...
# 37  https://www.dataforthai.com/company/0105545103...
# 38  https://www.dataforthai.com/company/0105552104...
# 39  https://www.dataforthai.com/company/0215555005...
# 40  https://www.dataforthai.com/company/0925561001...
# 41  https://www.dataforthai.com/company/0505535003...
# 42  https://www.dataforthai.com/company/0225565001...
# 43  https://www.dataforthai.com/company/0105562201...
# 44  https://www.dataforthai.com/company/0105559128...
# 45  https://www.dataforthai.com/company/0105526000...
# 46  https://www.dataforthai.com/company/0105560207...
# 47  https://www.dataforthai.com/company/0575552000...
# 48  https://www.dataforthai.com/company/0105565022...
# 49  https://www.dataforthai.com/company/0365526000...
# 50  https://www.dataforthai.com/company/0105551108...
# 51  https://www.dataforthai.com/company/0105544029...
# 52  https://www.dataforthai.com/company/0105534097...
#
#    สมัครงาน / ดูตำแหน่งงานว่าง วันที่ร้าง วันที่เลิก
# 0    ดูตำแหน่งงานจาก JOBTOPGUN        NaN        NaN
# 1                          NaN        NaN        NaN
# 2                          NaN        NaN        NaN
# 3                          NaN        NaN        NaN
# 4                          NaN        NaN        NaN
# 5                          NaN        NaN        NaN
# 6                          NaN        NaN        NaN
# 7                          NaN        NaN        NaN
# 8                          NaN        NaN        NaN
# 9                          NaN        NaN        NaN
# 10                         NaN        NaN        NaN
# 11                         NaN        NaN        NaN
# 12                         NaN        NaN        NaN
# 13                         NaN        NaN        NaN
# 14                         NaN        NaN        NaN
# 15                         NaN        NaN        NaN
# 16      ดูตำแหน่งงานจาก JOBBKK        NaN        NaN
# 17     ดูตำแหน่งงานจาก JOBTHAI        NaN        NaN
# 18                         NaN        NaN        NaN
# 19                         NaN        NaN        NaN
# 20                         NaN        NaN        NaN
# 21                         NaN        NaN        NaN
# 22                         NaN        NaN        NaN
# 23                         NaN        NaN        NaN
# 24                         NaN        NaN        NaN
# 25                         NaN        NaN        NaN
# 26                         NaN        NaN        NaN
# 27                         NaN        NaN        NaN
# 28                         NaN        NaN        NaN
# 29                         NaN        NaN        NaN
# 30                         NaN        NaN        NaN
# 31                         NaN        NaN        NaN
# 32                         NaN        NaN        NaN
# 33                         NaN        NaN        NaN
# 34                         NaN        NaN        NaN
# 35                         NaN        NaN        NaN
# 36                         NaN        NaN        NaN
# 37                         NaN        NaN        NaN
# 38                         NaN        NaN        NaN
# 39                         NaN        NaN        NaN
# 40                         NaN        NaN        NaN
# 41                         NaN        NaN        NaN
# 42                         NaN        NaN        NaN
# 43                         NaN        NaN        NaN
# 44                         NaN        NaN        NaN
# 45                         NaN        NaN        NaN
# 46                         NaN        NaN        NaN
# 47                         NaN        NaN        NaN
# 48                         NaN        NaN        NaN
# 49                         NaN        NaN        NaN
# 50                         NaN        NaN        NaN
# 51                         NaN        NaN        NaN
# 52                         NaN        NaN        NaN

# %%
# Outer Join
join_df = pd.merge(df1, result, on='เลขทะเบียน', how='outer')
# print("\nOuter Join:")

# join_df = pd.concat([df1, result], ignore_index=True)

# join_df = join_df.drop(columns=['value1_y'])

# print(outer_join_df)
join_df.columns.tolist()
# join_df
# Out:
# ['เลขทะเบียน',
#  'ชื่อบริษัทภาษาไทย_x',
#  'ชื่อบริษัทภาษาอังกฤษ_x',
#  'ประกอบธุรกิจ_x',
#  'หมวดธุรกิจ_x',
#  'สถานะ_x',
#  'วันที่จดทะเบียน_x',
#  'ทุนจดทะเบียน_x',
#  'ที่ตั้ง_x',
#  'ข้อมูลสำหรับการติดต่อ_x',
#  'เบอร์โทร_x',
#  'Website_x',
#  'ก่อตั้งโดย_x',
#  'หลักทรัพย์_x',
#  'ที่มา_x',
#  'สมัครงาน / ดูตำแหน่งงานว่าง_x',
#  'วันที่ร้าง_x',
#  'วันที่เลิก_x',
#  'ชื่อบริษัทภาษาไทย_y',
#  'ชื่อบริษัทภาษาอังกฤษ_y',
#  'ประกอบธุรกิจ_y',
#  'หมวดธุรกิจ_y',
#  'สถานะ_y',
#  'วันที่จดทะเบียน_y',
#  'ทุนจดทะเบียน_y',
#  'ที่ตั้ง_y',
#  'ข้อมูลสำหรับการติดต่อ_y',
#  'เบอร์โทร_y',
#  'Website_y',
#  'ก่อตั้งโดย_y',
#  'หลักทรัพย์_y',
#  'ที่มา_y',
#  'สมัครงาน / ดูตำแหน่งงานว่าง_y',
#  'วันที่ร้าง_y',
#  'วันที่เลิก_y']

# %%
# result[result['เลขทะเบียน'].str.len() != 13]

# %%
# file_name = 'test.csv'
# file_path = '/Users/bew/Downloads/'

# # Combine the file path and file name
# full_path = os.path.join(file_path, file_name)

# result.to_csv(full_path, sep=',', index=False, header=True, encoding='utf-8')

# %%
# # Step 1: Remove commas from the strings
# df['Capital'] = df['Capital'].str.replace(',', '')

# # Step 2: Convert the strings to numeric type (int or float)
# df['Capital'] = pd.to_numeric(df['Capital'])

# # Display the DataFrame to verify the changes
# df
